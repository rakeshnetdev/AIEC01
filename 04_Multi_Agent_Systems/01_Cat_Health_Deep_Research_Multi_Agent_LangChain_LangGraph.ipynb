# %% [markdown]
# # Multi-Agent Deep Research for Cat Nutrition and Obesity
#
# Deep research is not one enormous prompt. It is a composition of familiar patterns:
#
# ```text
# scope -> delegate -> search -> verify -> write -> audit -> evaluate
# ```
#
# In this notebook, every reasoning actor is built with LangChain's `create_agent`.
# A small LangGraph workflow controls the lifecycle, parallel-friendly delegation,
# optional human clarification, persistence, and deterministic checks.
#
# The worked example asks:
#
# > What does current evidence say about preventing and safely managing obesity in adult indoor cats?
#
# This is an educational research workflow. It does not diagnose an animal or create
# an individualized feeding or weight-loss plan.
#
# ## Learning Outcomes
#
# By the end of this notebook, you will be able to:
#
# - Explain when multiple agents improve context isolation and role specialization.
# - Build named `create_agent` workers and expose them as high-level tools.
# - Use structured outputs as contracts between research stages.
# - Combine agentic loops with a deterministic LangGraph workflow.
# - Pause and resume a workflow with `interrupt()` and `Command(resume=...)`.
# - Track source URLs through research, verification, writing, and citation auditing.
# - Reason about research quality, latency, and API cost as explicit design tradeoffs.

# %% [markdown]
# ## Table of Contents
#
# - **Breakout Room #1: Specialized Agents and Delegation**
#   - Task 1: Environment Setup
#   - Task 2: Define Typed Handoff Contracts
#   - Task 3: Configure Tavily Search and Extract
#   - Task 4: Build Specialized Research Workers
#   - Task 5: Wrap Workers as Supervisor Tools
#   - Task 6: Build the Research Supervisor
#   - Activity #1: Add a New Specialist
# - **Breakout Room #2: End-to-End Deep Research Workflow**
#   - Task 7: Build the Scoper and Clarification Path
#   - Task 8: Build Verification, Writing, and Evaluation Agents
#   - Task 9: Define LangGraph State and Nodes
#   - Task 10: Compile, Visualize, and Stream the Workflow
#   - Task 11: Audit Citations Deterministically
#   - Task 12: Run the Full Deep Research System
#   - Activity #2: Compare Research Depth and Cost
#   - Advanced Build: Add a Local-Corpus Specialist

# %% [markdown]
# ---
# # Breakout Room #1
# ## Specialized Agents and Delegation
#
# A multi-agent system is useful when independent actors need different prompts,
# tools, context, or optimization targets.
#
# Our supervisor does not search the web directly. It delegates bounded research
# tasks to workers and receives compact, typed findings. This keeps low-level search
# traces out of the supervisor's context.

# %% [markdown]
# ## Task 1: Environment Setup
#
# From the `04_Multi_Agent_Systems` folder:
#
# ```bash
# uv sync
# ```
#
# Then select the environment created by uv as this notebook's kernel.
#
# Required accounts:
#
# - OpenAI API
# - Tavily API
#
# LangSmith tracing is optional but strongly recommended for inspecting nested agents.

# %% [markdown]
# ### Imports

# %%
from __future__ import annotations

import json
import os
import re
from datetime import date
from getpass import getpass
from typing import Literal, TypedDict
from urllib.parse import urlsplit, urlunsplit

from IPython.display import Image, Markdown, display
from pydantic import BaseModel, Field

from langchain.agents import create_agent
from langchain.agents.middleware import (
    ModelCallLimitMiddleware,
    ToolCallLimitMiddleware,
)
from langchain.messages import ToolMessage
from langchain.tools import tool
from langchain_core.runnables import RunnableConfig
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilyExtract, TavilySearch

from langgraph.checkpoint.memory import InMemorySaver
from langgraph.graph import END, START, StateGraph
from langgraph.types import Command, interrupt

# %% [markdown]
# ### API Keys, Models, and Research Budgets
#
# The environment variables make the notebook easy to tune without editing code.
# Research depth is an application policy, not a mysterious property of the model.
#
# `AIM_SEARCH_CALL_LIMIT` limits Tavily searches per worker invocation.
# `AIM_WORKER_MODEL_CALL_LIMIT` bounds each worker's ReAct loop.

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")

if not os.environ.get("TAVILY_API_KEY"):
    os.environ["TAVILY_API_KEY"] = getpass("Tavily API Key: ")

if not os.environ.get("LANGSMITH_API_KEY"):
    os.environ["LANGSMITH_API_KEY"] = getpass("LangSmith API Key: ")

if not os.environ.get("LANGSMITH_TRACING"):
    os.environ["LANGSMITH_TRACING"] = "true"

os.environ.setdefault(
    "LANGSMITH_PROJECT",
    "aim-session-4-multi-agent-deep-research",
)

TODAY = date.today().isoformat()
CHAT_MODEL_NAME = os.environ.get("AIM_CHAT_MODEL", "gpt-5.4-mini")
WRITER_MODEL_NAME = os.environ.get("AIM_WRITER_MODEL", CHAT_MODEL_NAME)
SEARCH_DEPTH = os.environ.get("AIM_SEARCH_DEPTH", "advanced")
SEARCH_CALL_LIMIT = int(os.environ.get("AIM_SEARCH_CALL_LIMIT", "3"))
EXTRACT_CALL_LIMIT = int(os.environ.get("AIM_EXTRACT_CALL_LIMIT", "2"))
WORKER_MODEL_CALL_LIMIT = int(
    os.environ.get("AIM_WORKER_MODEL_CALL_LIMIT", "8")
)

llm = ChatOpenAI(model=CHAT_MODEL_NAME)
writer_llm = ChatOpenAI(model=WRITER_MODEL_NAME)

print(f"Date: {TODAY}")
print(f"General model: {CHAT_MODEL_NAME}")
print(f"Writer model: {WRITER_MODEL_NAME}")
print(f"Search depth: {SEARCH_DEPTH}")
print(f"Search calls per worker: {SEARCH_CALL_LIMIT}")
print(f"LangSmith tracing: {os.environ.get('LANGSMITH_TRACING', 'false')}")
# Out:
# Date: 2026-06-17
# General model: gpt-5.4-mini
# Writer model: gpt-5.4-mini
# Search depth: advanced
# Search calls per worker: 3
# LangSmith tracing: true

# %% [markdown]
# ## Task 2: Define Typed Handoff Contracts
#
# Free-form prose is difficult to validate and pass between application stages.
# Pydantic models make the handoff contracts explicit.
#
# Notice that source URLs are first-class data. The report writer will not be allowed
# to invent a new source that did not survive verification.

# %%
SpecialistName = Literal["guidelines", "evidence"]
ConfidenceLevel = Literal["high", "medium", "low"]


class ResearchTask(BaseModel):
    task_id: str = Field(description="Stable short identifier such as task-1")
    question: str = Field(description="Focused research question for one worker")
    specialist: SpecialistName
    rationale: str


class ResearchBrief(BaseModel):
    title: str
    objective: str
    audience: str
    scope_in: list[str]
    scope_out: list[str]
    safety_constraints: list[str]
    tasks: list[ResearchTask] = Field(min_length=3, max_length=3)


class ScopeDecision(BaseModel):
    needs_clarification: bool
    clarification_question: str | None = None
    assumptions: list[str] = Field(default_factory=list)
    brief: ResearchBrief | None = None


class SourceRecord(BaseModel):
    url: str
    title: str
    publisher: str
    published_date: str | None = None
    source_type: Literal[
        "guideline",
        "peer_reviewed",
        "government",
        "university",
        "professional_org",
        "other",
    ]
    authority_reason: str
    relevant_excerpt: str
    accessed_on: str


class ClaimRecord(BaseModel):
    claim: str
    source_urls: list[str] = Field(min_length=1)
    confidence: ConfidenceLevel
    caveat: str


class ResearchFindings(BaseModel):
    task_id: str
    specialist: SpecialistName
    summary: str
    sources: list[SourceRecord] = Field(default_factory=list)
    claims: list[ClaimRecord] = Field(default_factory=list)
    disagreements: list[str] = Field(default_factory=list)
    evidence_gaps: list[str] = Field(default_factory=list)
    errors: list[str] = Field(default_factory=list)


class ResearchDossier(BaseModel):
    brief_title: str
    findings: list[ResearchFindings] = Field(default_factory=list)
    cross_source_synthesis: list[str] = Field(default_factory=list)
    unresolved_gaps: list[str] = Field(default_factory=list)


class RejectedSource(BaseModel):
    url: str
    reason: str


class VerificationReport(BaseModel):
    approved_sources: list[SourceRecord] = Field(default_factory=list)
    rejected_sources: list[RejectedSource] = Field(default_factory=list)
    verified_claims: list[ClaimRecord] = Field(default_factory=list)
    unsupported_claims: list[str] = Field(default_factory=list)
    disagreements: list[str] = Field(default_factory=list)
    evidence_gaps: list[str] = Field(default_factory=list)
    verification_summary: str


class FinalReport(BaseModel):
    title: str
    executive_summary: str
    report_markdown: str
    limitations: list[str]
    medical_safety_note: str
    citations: list[str] = Field(
        description="Ordered list of source URLs cited in report_markdown"
    )


class CitationAudit(BaseModel):
    cited_urls: list[str]
    unknown_urls: list[str]
    duplicate_urls: list[str]
    approved_but_uncited: list[str]
    missing_marker_numbers: list[int]
    passed: bool


class ReportEvaluation(BaseModel):
    coverage: int = Field(ge=1, le=5)
    synthesis: int = Field(ge=1, le=5)
    source_quality: int = Field(ge=1, le=5)
    citation_integrity: int = Field(ge=1, le=5)
    uncertainty_handling: int = Field(ge=1, le=5)
    medical_safety: int = Field(ge=1, le=5)
    strengths: list[str]
    improvements: list[str]
    passed: bool

# %% [markdown]
# #### ❓Question #1
#
# Why is a typed handoff safer than asking each agent to return "a useful summary"?
# Which fields are application guarantees, and which still depend on model judgment?
#
# ##### ✅ Answer:
#
# ❓ Question #1
#
# Typed handoffs are safer because the next agent receives structured and validated data instead of vague natural language, which reduces ambiguity and makes the system more reliable.
#
# The application guarantees come from the schema (like Pydantic), which ensures that required fields are present, data types are correct, lists stay within limits, and fields with fixed options stay within the allowed set; this makes fields like task_id, specialist, source_urls, approved_sources, and citations reliable once validation passes.
#
# However, the model still controls the actual content inside those fields, such as whether a source is truly strong, whether the reasoning is sound, whether a summary is accurate, and whether a confidence level is justified, so while the structure is guaranteed, the quality of the information still depends on the model and may need further verification.

# %% [markdown]
# ## Task 3: Configure Tavily Search and Extract
#
# Search discovers candidate sources. Extract reads selected pages more deeply.
# We deliberately do not use Tavily's Research API because the goal is to build the
# multi-agent research behavior ourselves.

# %%
tavily_search = TavilySearch(
    max_results=5,
    topic="general",
    search_depth=SEARCH_DEPTH,
    include_answer=False,
    include_raw_content=False,
)

tavily_extract = TavilyExtract(
    extract_depth="advanced",
    format="markdown",
    chunks_per_source=3,
)

print(tavily_search.name)
print(tavily_extract.name)
# Out:
# tavily_search
# tavily_extract

# %% [markdown]
# The search and extraction tools return URLs in tool messages. We will retain only
# source URLs that were actually observed in those tool results. This does not prove
# a claim is correct, but it prevents an agent from adding an entirely unobserved URL
# to the source ledger.

# %%
URL_PATTERN = re.compile(r"https?://[^\s\]\[()<>{}\"']+")


def normalize_url(url: str) -> str:
    '''Normalize a URL for deterministic ledger comparison.'''
    cleaned = url.strip().rstrip(".,;:!?)")
    parts = urlsplit(cleaned)
    path = parts.path.rstrip("/") or "/"
    return urlunsplit(
        (
            parts.scheme.lower(),
            parts.netloc.lower(),
            path,
            parts.query,
            "",
        )
    )


def urls_in_value(value: object) -> set[str]:
    '''Extract normalized URLs from strings or JSON-like tool content.'''
    text = value if isinstance(value, str) else json.dumps(value, default=str)
    return {normalize_url(match) for match in URL_PATTERN.findall(text)}


def observed_tool_urls(agent_result: dict) -> set[str]:
    observed: set[str] = set()
    for message in agent_result.get("messages", []):
        if isinstance(message, ToolMessage):
            observed.update(urls_in_value(message.content))
    return observed


def sanitize_findings(
    findings: ResearchFindings,
    observed_urls: set[str],
) -> ResearchFindings:
    '''Drop sources and claims that cannot be traced to worker tool output.'''
    approved_sources = [
        source
        for source in findings.sources
        if normalize_url(source.url) in observed_urls
    ]
    approved_urls = {normalize_url(source.url) for source in approved_sources}

    approved_claims = []
    dropped_claims = []
    for claim in findings.claims:
        traced_urls = [
            url
            for url in claim.source_urls
            if normalize_url(url) in approved_urls
        ]
        if traced_urls:
            approved_claims.append(
                claim.model_copy(update={"source_urls": traced_urls})
            )
        else:
            dropped_claims.append(
                f"Untraced claim removed before supervision: {claim.claim}"
            )

    errors = list(findings.errors)
    if findings.sources and not approved_sources:
        errors.append(
            "The worker returned sources, but none of their URLs appeared "
            "in its search or extraction tool messages."
        )

    return findings.model_copy(
        update={
            "sources": approved_sources,
            "claims": approved_claims,
            "evidence_gaps": findings.evidence_gaps + dropped_claims,
            "errors": errors,
        }
    )


def sanitize_dossier(
    dossier: ResearchDossier,
    brief: ResearchBrief,
    observed_urls: set[str],
) -> ResearchDossier:
    '''Enforce worker URL provenance and record missing delegated tasks.'''
    task_by_id = {task.task_id: task for task in brief.tasks}
    sanitized_findings = []
    unexpected_findings = []
    for finding in dossier.findings:
        task = task_by_id.get(finding.task_id)
        if task is None:
            unexpected_findings.append(
                f"Unexpected findings returned for {finding.task_id}."
            )
            continue
        normalized_finding = finding.model_copy(
            update={"specialist": task.specialist}
        )
        sanitized_findings.append(
            sanitize_findings(normalized_finding, observed_urls)
        )
    returned_task_ids = {
        finding.task_id for finding in sanitized_findings
    }
    missing_tasks = [
        f"No findings returned for {task.task_id}: {task.question}"
        for task in brief.tasks
        if task.task_id not in returned_task_ids
    ]
    return dossier.model_copy(
        update={
            "brief_title": brief.title,
            "findings": sanitized_findings,
            "unresolved_gaps": (
                dossier.unresolved_gaps
                + unexpected_findings
                + missing_tasks
            ),
        }
    )


def sanitize_verification(
    verification: VerificationReport,
    observed_urls: set[str],
) -> VerificationReport:
    '''Keep only sources and claims traced to verifier tool output.'''
    approved_sources = [
        source
        for source in verification.approved_sources
        if normalize_url(source.url) in observed_urls
    ]
    approved_urls = {
        normalize_url(source.url) for source in approved_sources
    }
    verified_claims = []
    unsupported_claims = list(verification.unsupported_claims)
    for claim in verification.verified_claims:
        traced_urls = [
            url
            for url in claim.source_urls
            if normalize_url(url) in approved_urls
        ]
        if traced_urls:
            verified_claims.append(
                claim.model_copy(update={"source_urls": traced_urls})
            )
        else:
            unsupported_claims.append(
                f"Untraced verifier claim removed: {claim.claim}"
            )

    evidence_gaps = list(verification.evidence_gaps)
    if verification.approved_sources and not approved_sources:
        evidence_gaps.append(
            "The verifier approved sources, but none appeared in its tool output."
        )

    return verification.model_copy(
        update={
            "approved_sources": approved_sources,
            "verified_claims": verified_claims,
            "unsupported_claims": unsupported_claims,
            "evidence_gaps": evidence_gaps,
        }
    )

# %% [markdown]
# ## Task 4: Build Specialized Research Workers
#
# Both workers use the same model and tools, but they have different search priorities
# and evaluation criteria.
#
# - The **guideline researcher** prioritizes professional and public-health guidance.
# - The **evidence researcher** prioritizes peer-reviewed studies and actively tests
#   common nutrition claims.
#
# The workers return `ResearchFindings`, not final prose for the user.

# %%
def worker_middleware():
    '''Create fresh operational limits for one research agent.'''
    return [
        ModelCallLimitMiddleware(
            run_limit=WORKER_MODEL_CALL_LIMIT,
            exit_behavior="end",
        ),
        ToolCallLimitMiddleware(
            tool_name=tavily_search.name,
            run_limit=SEARCH_CALL_LIMIT,
            exit_behavior="continue",
        ),
        ToolCallLimitMiddleware(
            tool_name=tavily_extract.name,
            run_limit=EXTRACT_CALL_LIMIT,
            exit_behavior="continue",
        ),
    ]


GUIDELINE_RESEARCHER_PROMPT = f'''
You are the guideline specialist in a multi-agent veterinary research system.
Today's date is {TODAY}.

Research only the assigned task. Prioritize primary or authoritative sources:
AAFP, AAHA, WSAVA, AVMA, government agencies, veterinary schools, and recognized
veterinary nutrition organizations. Search before making factual claims. Extract
promising pages when snippets are not enough.

Return exactly the ResearchFindings schema. Every source URL and every claim URL
must come from a search or extraction tool result in this run. Explain why each
source is authoritative. Record disagreement and missing evidence. Do not diagnose,
prescribe, calculate calories, or create an individualized weight-loss plan.
Your final response is the only information the supervisor receives.
'''

EVIDENCE_RESEARCHER_PROMPT = f'''
You are the evidence specialist in a multi-agent veterinary research system.
Today's date is {TODAY}.

Research only the assigned task. Prioritize peer-reviewed studies, systematic
reviews, consensus statements, university sources, and primary publications.
Challenge broad claims about wet versus dry food, meal frequency, activity,
energy restriction, body-condition scoring, and safe rates of feline weight loss.
Distinguish association from causation and guidelines from controlled evidence.
Search before making factual claims and extract promising pages when needed.

Return exactly the ResearchFindings schema. Every source URL and every claim URL
must come from a search or extraction tool result in this run. Preserve uncertainty,
conflicting findings, study limitations, and unanswered questions. Do not diagnose,
prescribe, calculate calories, or create an individualized weight-loss plan.
Your final response is the only information the supervisor receives.
'''

guideline_researcher = create_agent(
    model=llm,
    tools=[tavily_search, tavily_extract],
    system_prompt=GUIDELINE_RESEARCHER_PROMPT,
    middleware=worker_middleware(),
    response_format=ResearchFindings,
    name="guideline_researcher",
)

evidence_researcher = create_agent(
    model=llm,
    tools=[tavily_search, tavily_extract],
    system_prompt=EVIDENCE_RESEARCHER_PROMPT,
    middleware=worker_middleware(),
    response_format=ResearchFindings,
    name="evidence_researcher",
)

print("Created named guideline and evidence research agents.")
# Out:
# Created named guideline and evidence research agents.

# %% [markdown]
# ## Task 5: Wrap Workers as Supervisor Tools
#
# This is the central subagent pattern:
#
# ```text
# supervisor -> high-level worker tool -> create_agent worker -> Tavily tools
# ```
#
# The supervisor sees one compact JSON result per worker call. It does not receive the
# worker's entire message history.
#
# The wrappers also turn worker failures into explicit gaps so one failed research
# stream does not erase successful work from another stream.

# %%
def failed_findings(
    task: ResearchTask,
    specialist: SpecialistName,
    error: Exception,
) -> ResearchFindings:
    return ResearchFindings(
        task_id=task.task_id,
        specialist=specialist,
        summary="The delegated research task did not complete.",
        evidence_gaps=[task.question],
        errors=[f"{type(error).__name__}: {error}"],
    )


async def run_worker(
    agent,
    task_json: str,
    specialist: SpecialistName,
) -> ResearchFindings:
    try:
        task = ResearchTask.model_validate_json(task_json)
    except Exception as exc:
        return ResearchFindings(
            task_id="invalid-task",
            specialist=specialist,
            summary="The supervisor supplied an invalid research task.",
            evidence_gaps=["The delegated task could not be parsed."],
            errors=[f"{type(exc).__name__}: {exc}"],
        )

    try:
        result = await agent.ainvoke(
            {
                "messages": [
                    {
                        "role": "user",
                        "content": (
                            "Complete this delegated research task and return "
                            f"the required structured findings:\n{task_json}"
                        ),
                    }
                ]
            }
        )
        findings = ResearchFindings.model_validate(
            result["structured_response"]
        )
        findings = findings.model_copy(
            update={
                "task_id": task.task_id,
                "specialist": specialist,
            }
        )
        return sanitize_findings(
            findings,
            observed_tool_urls(result),
        )
    except Exception as exc:
        return failed_findings(task, specialist, exc)


@tool(
    "research_guidelines",
    description=(
        "Delegate one structured ResearchTask to the veterinary guideline "
        "specialist. Input must be the task's JSON representation."
    ),
)
async def research_guidelines(task_json: str) -> str:
    findings = await run_worker(
        guideline_researcher,
        task_json,
        "guidelines",
    )
    return findings.model_dump_json(indent=2)


@tool(
    "research_evidence",
    description=(
        "Delegate one structured ResearchTask to the peer-reviewed evidence "
        "specialist. Input must be the task's JSON representation."
    ),
)
async def research_evidence(task_json: str) -> str:
    findings = await run_worker(
        evidence_researcher,
        task_json,
        "evidence",
    )
    return findings.model_dump_json(indent=2)

# %% [markdown]
# #### ❓Question #2
#
# What context remains isolated inside each worker? What information crosses the
# worker-supervisor boundary? How does this affect cost and debuggability?
#
# ##### ✅ Answer:
#
# Inside each worker, the local research loop stays isolated: its prompt, message history, retries, extraction results, intermediate reasoning, and dead ends do not get promoted to the supervisor.
#
# The worker-supervisor boundary should carry only compact, structured handoffs, which is the same basic idea behind supervisor-style multi-agent systems where the supervisor coordinates workers and receives their outputs back.
#
# ##### What crosses the boundary?
#
# Typically, the supervisor sends a delegated task in structured form and receives one distilled result back. In our example, that means the `ResearchTask` JSON goes in, and a `ResearchFindings` payload comes out with explicit fields like `sources`, `claims`, `disagreements`, `evidence_gaps`, and `errors`.
#
# ##### Cost and debuggability
#
# This design lowers cost because the supervisor does not need to retain every raw search hit, retry, or scratchpad from every worker in its own context windowm, it only carries the reduced result.
#
# It also improves debuggability because traces stay readable and failures stay localized to the worker that produced them, while the trade-off is that understanding "why " a worker concluded something usually requires inspecting the worker trace rather than only the supervisor state.

# %% [markdown]
# ## Task 6: Build the Research Supervisor
#
# The supervisor receives exactly three tasks from the scoper. It should emit all
# independent worker calls in the same model turn when possible. LangChain's agent
# tool node can execute multiple tool calls concurrently.
#
# This remains agentic: the model chooses the worker for each task and may revise its
# approach after reading worker outputs. Operational middleware prevents an unbounded
# delegation loop.

# %%
SUPERVISOR_PROMPT = f'''
You are the lead researcher coordinating a bounded multi-agent investigation.
Today's date is {TODAY}.

You receive a validated ResearchBrief containing exactly three tasks.
For every task:
- Call research_guidelines when specialist is guidelines.
- Call research_evidence when specialist is evidence.
- Pass the complete ResearchTask as JSON.

The tasks are independent. Emit all possible worker tool calls together in one
model turn so the runtime can execute them concurrently. After all tools return,
combine their structured outputs into one ResearchDossier. Preserve errors,
disagreements, and evidence gaps. Do not create new sources or URLs. Do not write
the final user report.
'''

research_supervisor = create_agent(
    model=llm,
    tools=[research_guidelines, research_evidence],
    system_prompt=SUPERVISOR_PROMPT,
    middleware=[
        ModelCallLimitMiddleware(run_limit=6, exit_behavior="end"),
        ToolCallLimitMiddleware(
            tool_name=research_guidelines.name,
            run_limit=3,
            exit_behavior="continue",
        ),
        ToolCallLimitMiddleware(
            tool_name=research_evidence.name,
            run_limit=3,
            exit_behavior="continue",
        ),
    ],
    response_format=ResearchDossier,
    name="research_supervisor",
)

print("Research supervisor ready.")
# Out:
# Research supervisor ready.

# %% [markdown]
# ## 🏗️ Activity #1: Add a New Specialist
#
# Add a third specialist without giving the supervisor more low-level tools.
#
# Choose one:
#
# - A source-methodology specialist that scores study design and sample quality
# - A veterinary communication specialist that identifies misleading public claims
# - A cost-and-feasibility specialist that compares practical interventions
#
# Requirements:
#
# 1. Create a named `create_agent` worker with a focused prompt.
# 2. Give it only the tools it needs.
# 3. Wrap it in one high-level supervisor tool.
# 4. Extend `SpecialistName` and the scoper's task instructions.
# 5. Explain what context should and should not cross the boundary.

# %%
# Activity #1 workspace
# NEW_SPECIALIST_PROMPT = ...
# new_specialist = create_agent(...)
#
# @tool(...)
# async def research_new_specialty(task_json: str) -> str:
#     ...

from typing import Literal

# Rebuild the specialist-aware schemas so the new worker can be assigned by the scoper.
# This cell intentionally redefines the affected classes from Task 2.
SpecialistName = Literal["guidelines", "evidence", "methodology"]
ConfidenceLevel = Literal["high", "medium", "low"]


class ResearchTask(BaseModel):
    task_id: str = Field(description="Stable short identifier such as task-1")
    question: str = Field(description="Focused research question for one worker")
    specialist: SpecialistName
    rationale: str


class ResearchBrief(BaseModel):
    title: str
    objective: str
    audience: str
    scope_in: list[str]
    scope_out: list[str]
    safety_constraints: list[str]
    tasks: list[ResearchTask] = Field(min_length=3, max_length=3)


class ScopeDecision(BaseModel):
    needs_clarification: bool
    clarification_question: str | None = None
    assumptions: list[str] = Field(default_factory=list)
    brief: ResearchBrief | None = None


class ResearchFindings(BaseModel):
    task_id: str
    specialist: SpecialistName
    summary: str
    sources: list[SourceRecord] = Field(default_factory=list)
    claims: list[ClaimRecord] = Field(default_factory=list)
    disagreements: list[str] = Field(default_factory=list)
    evidence_gaps: list[str] = Field(default_factory=list)
    errors: list[str] = Field(default_factory=list)


class ResearchDossier(BaseModel):
    brief_title: str
    findings: list[ResearchFindings] = Field(default_factory=list)
    cross_source_synthesis: list[str] = Field(default_factory=list)
    unresolved_gaps: list[str] = Field(default_factory=list)


METHODOLOGY_RESEARCHER_PROMPT = f'''
You are the methodology specialist in a multi-agent veterinary research system.
Today's date is {TODAY}.

Research only the assigned task. Prioritize peer-reviewed studies, systematic
reviews, consensus statements, and university summaries that describe study
design, sample quality, endpoints, confounding, and applicability.

Your job is not to restate every nutrition claim. Your job is to judge how much
confidence the team should place in those claims.

For each strong or weak claim, look for:
- study type and whether it is interventional or observational,
- sample size and whether the population matches adult indoor cats,
- meaningful limitations or confounders,
- disagreement between guideline language and controlled evidence.

Search before making factual claims. Extract promising pages when snippets are
not enough.

Return exactly the ResearchFindings schema. Every source URL and every claim URL
must come from a search or extraction tool result in this run. Preserve
uncertainty. Do not diagnose, prescribe, calculate calories, or create an
individualized plan. Your final response is the only information the supervisor
receives.
'''


methodology_researcher = create_agent(
    model=llm,
    tools=[tavily_search, tavily_extract],
    system_prompt=METHODOLOGY_RESEARCHER_PROMPT,
    middleware=worker_middleware(),
    response_format=ResearchFindings,
    name="methodology_researcher",
)


@tool(
    "research_methodology",
    description=(
        "Delegate one structured ResearchTask to the source-methodology "
        "specialist. Input must be the task's JSON representation."
    ),
)
async def research_methodology(task_json: str) -> str:
    findings = await run_worker(
        methodology_researcher,
        task_json,
        "methodology",
    )
    return findings.model_dump_json(indent=2)


SCOPER_PROMPT = f'''
You scope veterinary deep-research requests. Today's date is {TODAY}.

Return a ScopeDecision.

Ask exactly one clarification question only when proceeding would materially
change the research objective, audience, population, or safety boundary.
Otherwise record reasonable assumptions and produce a ResearchBrief with exactly
three independent tasks.

For feline nutrition and obesity:
- Include prevention, assessment, and safe management evidence when relevant.
- Exclude diagnosis, prescriptions, calorie calculations, and personalized plans.
- Assign each task to guidelines, evidence, or methodology.
- Use methodology when a task is mainly about study quality, conflicting evidence,
  or how much trust to place in broad claims.
- Make tasks independent enough to research concurrently.
- Include a veterinary-review safety constraint.
'''


scoper_agent = create_agent(
    model=llm,
    tools=[],
    system_prompt=SCOPER_PROMPT,
    response_format=ScopeDecision,
    name="research_scoper",
)


SUPERVISOR_PROMPT = f'''
You are the lead researcher coordinating a bounded multi-agent investigation.
Today's date is {TODAY}.

You receive a validated ResearchBrief containing exactly three tasks.
For every task:
- Call research_guidelines when specialist is guidelines.
- Call research_evidence when specialist is evidence.
- Call research_methodology when specialist is methodology.
- Pass the complete ResearchTask as JSON.

The tasks are independent. Emit all possible worker tool calls together in one
model turn so the runtime can execute them concurrently. After all tools return,
combine their structured outputs into one ResearchDossier. Preserve errors,
disagreements, and evidence gaps. Do not create new sources or URLs. Do not
write the final user report.
'''


research_supervisor = create_agent(
    model=llm,
    tools=[research_guidelines, research_evidence, research_methodology],
    system_prompt=SUPERVISOR_PROMPT,
    middleware=[
        ModelCallLimitMiddleware(run_limit=6, exit_behavior="end"),
        ToolCallLimitMiddleware(
            tool_name=research_guidelines.name,
            run_limit=3,
            exit_behavior="continue",
        ),
        ToolCallLimitMiddleware(
            tool_name=research_evidence.name,
            run_limit=3,
            exit_behavior="continue",
        ),
        ToolCallLimitMiddleware(
            tool_name=research_methodology.name,
            run_limit=3,
            exit_behavior="continue",
        ),
    ],
    response_format=ResearchDossier,
    name="research_supervisor",
)

print("Added methodology specialist, wrapper tool, scoper support, and supervisor support.")
# Out:
# Added methodology specialist, wrapper tool, scoper support, and supervisor support.

# %% [markdown]
# ### 🤔 Activity #1 Reflections
#
# - What unique responsibility did the specialist receive?
# - Why is a separate context window useful for this responsibility?
# - What additional latency and cost does the specialist introduce?
#
# ##### ✅ Answer:
#
# - For a source-methodology specialist, the unique responsibility is evaluating **how trustworthy a study is**, not just summarizing what it says.
#
#     ex: The methodology specialist (named "methodology" in SpecialistName = Literal["guidelines", "evidence", "methodology"]) is responsible for judging study trustworthiness, not summarizing what the study claims. The METHODOLOGY_RESEARCHER_PROMPT explicitly states.
#
# - The specialist has its own narrow search path and criteria—sample size, study design, endpoints, confounding, and applicability—that would pollute the supervisor's context if merged into it. The supervisor only receives the distilled ResearchFindings schema with sources, claims, disagreements, evidence_gaps, and errors, not the raw search-and-extraction trail. This isolation keeps the supervisor's context compact while the worker handles the full methodological back-and-forth.
#
# - The trade-off is added overhead: one more worker loop means more model calls, more retrieval/extraction steps, and more latency before the supervisor can combine everything into a final answer.
#
#     ex: One extra worker loop adds:
#     1. more model calls (the methodology_researcher agent via run_worker).
#     2.  more search/extract calls (tavily_search and tavily_extract are the worker's tools).
#     3.  more latency before the supervisor can synthesize all three workers' outputs into the final ResearchDossier.

# %% [markdown]
# ---
# # Breakout Room #2
# ## End-to-End Deep Research Workflow
#
# `create_agent` is excellent for a model-tools loop. It should not be forced to own
# every deterministic lifecycle rule.
#
# LangGraph will make these application stages explicit:
#
# ```text
# scope -> clarify? -> research -> verify -> write -> audit -> evaluate
# ```

# %% [markdown]
# ## Task 7: Build the Scoper and Clarification Path
#
# The scoper converts an open-ended request into exactly three bounded research tasks.
# If a request is too ambiguous, it returns one high-value clarification question.
#
# LangGraph, not the scoper, owns the pause and resume behavior.

# %%
SCOPER_PROMPT = f'''
You scope veterinary deep-research requests. Today's date is {TODAY}.

Return a ScopeDecision.

Ask exactly one clarification question only when proceeding would materially change
the research objective, audience, population, or safety boundary. Otherwise record
reasonable assumptions and produce a ResearchBrief with exactly three independent
tasks.

For feline nutrition and obesity:
- Include prevention, assessment, and safe management evidence when relevant.
- Exclude diagnosis, prescriptions, calorie calculations, and personalized plans.
- Assign each task to guidelines or evidence.
- Make tasks independent enough to research concurrently.
- Include a veterinary-review safety constraint.
'''

scoper_agent = create_agent(
    model=llm,
    tools=[],
    system_prompt=SCOPER_PROMPT,
    response_format=ScopeDecision,
    name="research_scoper",
)

# %% [markdown]
# ## Task 8: Build Verification, Writing, and Evaluation Agents
#
# Verification is separate from writing so the writer cannot quietly promote a weak
# source while composing polished prose.
#
# The writer receives only the verification report. The evaluator receives the final
# report, verification report, and deterministic citation audit.

# %%
VERIFIER_PROMPT = f'''
You verify a multi-agent veterinary research dossier. Today's date is {TODAY}.

Use Tavily Extract to inspect candidate URLs, preferably in batches. Use Tavily
Search only when a URL cannot be checked or an important claim needs a stronger
source. Approve a source only if the URL resolves through a tool result and the
source supports the associated claim. Reject unverifiable, irrelevant, low-quality,
or contradictory sources with a reason.

Return VerificationReport. Keep only claims supported by approved source URLs.
Preserve material disagreement and uncertainty. Do not invent replacement URLs.
Do not provide individualized veterinary advice.
'''

verifier_agent = create_agent(
    model=llm,
    tools=[tavily_extract, tavily_search],
    system_prompt=VERIFIER_PROMPT,
    middleware=[
        ModelCallLimitMiddleware(run_limit=7, exit_behavior="end"),
        ToolCallLimitMiddleware(
            tool_name=tavily_extract.name,
            run_limit=3,
            exit_behavior="continue",
        ),
        ToolCallLimitMiddleware(
            tool_name=tavily_search.name,
            run_limit=2,
            exit_behavior="continue",
        ),
    ],
    response_format=VerificationReport,
    name="source_verifier",
)

WRITER_PROMPT = f'''
You write the final report for a veterinary deep-research system.
Today's date is {TODAY}.

Use only verified claims and approved sources in the supplied VerificationReport.
Do not introduce external facts or URLs. Produce one coherent report rather than
concatenating worker summaries.

In report_markdown:
- Separate strong conclusions from tentative evidence.
- Explain meaningful disagreement.
- Use numbered citation markers such as [1], [2], and [3].
- End with a Sources section mapping every marker to its exact approved URL.
- Avoid diagnosis, prescriptions, calorie calculations, and individualized plans.
- State that feline weight-loss plans require veterinary supervision and that
  overly rapid weight loss can be dangerous.

The citations field must contain the exact URLs in marker order.
'''

writer_agent = create_agent(
    model=writer_llm,
    tools=[],
    system_prompt=WRITER_PROMPT,
    response_format=FinalReport,
    name="report_writer",
)

EVALUATOR_PROMPT = '''
You evaluate a deep-research report against its brief, verification report, and
deterministic citation audit.

Score each criterion from 1 to 5. Pass only when:
- every score is at least 3,
- citation_integrity and medical_safety are at least 4,
- the deterministic citation audit passed.

Do not reward confident wording when evidence is weak.
'''

evaluator_agent = create_agent(
    model=llm,
    tools=[],
    system_prompt=EVALUATOR_PROMPT,
    response_format=ReportEvaluation,
    name="report_evaluator",
)

# %% [markdown]
# ## Task 9: Define LangGraph State and Nodes
#
# The graph state is the application record. Each node reads the fields it needs and
# writes a typed result for the next stage.

# %%
class DeepResearchState(TypedDict, total=False):
    query: str
    clarification_answer: str
    scope_decision: ScopeDecision
    brief: ResearchBrief
    dossier: ResearchDossier
    verification: VerificationReport
    report: FinalReport
    citation_audit: CitationAudit
    evaluation: ReportEvaluation
    errors: list[str]

# %%
async def scope_node(
    state: DeepResearchState,
    config: RunnableConfig,
) -> dict:
    clarification = state.get("clarification_answer")
    user_content = state["query"]
    if clarification:
        user_content += (
            "\n\nThe user answered the clarification question:\n"
            f"{clarification}"
        )

    result = await scoper_agent.ainvoke(
        {"messages": [{"role": "user", "content": user_content}]},
        config=config,
    )
    decision = ScopeDecision.model_validate(result["structured_response"])
    update = {"scope_decision": decision}
    if decision.brief is not None:
        update["brief"] = decision.brief
    return update


def route_after_scope(state: DeepResearchState) -> Literal["clarify", "research"]:
    decision = state["scope_decision"]
    if decision.needs_clarification or decision.brief is None:
        return "clarify"
    return "research"


def clarify_node(state: DeepResearchState) -> dict:
    decision = state["scope_decision"]
    question = (
        decision.clarification_question
        or "What outcome and audience should this research focus on?"
    )
    answer = interrupt(
        {
            "question": question,
            "original_query": state["query"],
        }
    )
    return {"clarification_answer": str(answer)}

# %%
def empty_dossier(brief: ResearchBrief, error: Exception) -> ResearchDossier:
    return ResearchDossier(
        brief_title=brief.title,
        unresolved_gaps=[
            "The research supervisor failed before producing a complete dossier.",
            f"{type(error).__name__}: {error}",
        ],
    )


async def research_node(
    state: DeepResearchState,
    config: RunnableConfig,
) -> dict:
    brief = state["brief"]
    try:
        result = await research_supervisor.ainvoke(
            {
                "messages": [
                    {
                        "role": "user",
                        "content": (
                            "Coordinate this research brief. Delegate every task "
                            "and return the structured dossier:\n"
                            f"{brief.model_dump_json(indent=2)}"
                        ),
                    }
                ]
            },
            config=config,
        )
        dossier = ResearchDossier.model_validate(
            result["structured_response"]
        )
        dossier = sanitize_dossier(
            dossier,
            brief,
            observed_tool_urls(result),
        )
        return {"dossier": dossier}
    except Exception as exc:
        return {
            "dossier": empty_dossier(brief, exc),
            "errors": state.get("errors", [])
            + [f"Research stage: {type(exc).__name__}: {exc}"],
        }


async def verify_node(
    state: DeepResearchState,
    config: RunnableConfig,
) -> dict:
    dossier = state["dossier"]
    try:
        result = await verifier_agent.ainvoke(
            {
                "messages": [
                    {
                        "role": "user",
                        "content": dossier.model_dump_json(indent=2),
                    }
                ]
            },
            config=config,
        )
        verification = VerificationReport.model_validate(
            result["structured_response"]
        )
        verification = sanitize_verification(
            verification,
            observed_tool_urls(result),
        )
        return {"verification": verification}
    except Exception as exc:
        all_claims = [
            claim.claim
            for finding in dossier.findings
            for claim in finding.claims
        ]
        fallback = VerificationReport(
            unsupported_claims=all_claims,
            evidence_gaps=dossier.unresolved_gaps
            + ["Verification did not complete."],
            verification_summary=(
                "No sources were approved because verification failed: "
                f"{type(exc).__name__}: {exc}"
            ),
        )
        return {
            "verification": fallback,
            "errors": state.get("errors", [])
            + [f"Verification stage: {type(exc).__name__}: {exc}"],
        }

# %%
async def write_node(
    state: DeepResearchState,
    config: RunnableConfig,
) -> dict:
    verification = state["verification"]
    brief = state["brief"]
    try:
        result = await writer_agent.ainvoke(
            {
                "messages": [
                    {
                        "role": "user",
                        "content": (
                            "Research brief:\n"
                            f"{brief.model_dump_json(indent=2)}\n\n"
                            "Verified evidence:\n"
                            f"{verification.model_dump_json(indent=2)}"
                        ),
                    }
                ]
            },
            config=config,
        )
        report = FinalReport.model_validate(result["structured_response"])
        return {"report": report}
    except Exception as exc:
        fallback = FinalReport(
            title=brief.title,
            executive_summary=(
                "A reliable report could not be generated from the available "
                "verified evidence."
            ),
            report_markdown=(
                "# Research incomplete\n\n"
                "The writing stage failed. Review the verification record and "
                "rerun the workflow before using any conclusions."
            ),
            limitations=[
                "The report-writing stage did not complete.",
                f"{type(exc).__name__}: {exc}",
            ],
            medical_safety_note=(
                "Consult a veterinarian before changing a cat's diet or "
                "weight-management plan."
            ),
            citations=[],
        )
        return {
            "report": fallback,
            "errors": state.get("errors", [])
            + [f"Writing stage: {type(exc).__name__}: {exc}"],
        }

# %% [markdown]
# ## Task 10: Deterministic Citation Auditing
#
# LLM verification and LLM evaluation are still model judgments. The citation audit is
# ordinary code. It checks whether every report URL belongs to the approved source
# ledger, whether URLs are duplicated, and whether numeric markers reference missing
# citation entries.

# %%
CITATION_MARKER_PATTERN = re.compile(r"\[(\d+)\]")


def audit_report_citations(
    report: FinalReport,
    verification: VerificationReport,
) -> CitationAudit:
    approved = {
        normalize_url(source.url)
        for source in verification.approved_sources
    }
    ordered_citations = [
        normalize_url(url)
        for url in report.citations
    ]
    urls_in_markdown = urls_in_value(report.report_markdown)
    cited = set(ordered_citations) | urls_in_markdown

    seen: set[str] = set()
    duplicates = []
    for url in ordered_citations:
        if url in seen and url not in duplicates:
            duplicates.append(url)
        seen.add(url)

    marker_numbers = {
        int(value)
        for value in CITATION_MARKER_PATTERN.findall(report.report_markdown)
    }
    missing_markers = sorted(
        number
        for number in marker_numbers
        if number < 1 or number > len(ordered_citations)
    )

    unknown = sorted(cited - approved)
    approved_but_uncited = sorted(approved - cited)
    passed = bool(cited) and not unknown and not duplicates and not missing_markers

    return CitationAudit(
        cited_urls=sorted(cited),
        unknown_urls=unknown,
        duplicate_urls=duplicates,
        approved_but_uncited=approved_but_uncited,
        missing_marker_numbers=missing_markers,
        passed=passed,
    )


def audit_node(state: DeepResearchState) -> dict:
    return {
        "citation_audit": audit_report_citations(
            state["report"],
            state["verification"],
        )
    }

# %%
async def evaluate_node(
    state: DeepResearchState,
    config: RunnableConfig,
) -> dict:
    try:
        payload = {
            "brief": state["brief"].model_dump(),
            "verification": state["verification"].model_dump(),
            "report": state["report"].model_dump(),
            "citation_audit": state["citation_audit"].model_dump(),
        }
        result = await evaluator_agent.ainvoke(
            {
                "messages": [
                    {
                        "role": "user",
                        "content": json.dumps(payload, indent=2),
                    }
                ]
            },
            config=config,
        )
        evaluation = ReportEvaluation.model_validate(
            result["structured_response"]
        )
        if not state["citation_audit"].passed and evaluation.passed:
            evaluation = evaluation.model_copy(
                update={
                    "passed": False,
                    "improvements": evaluation.improvements
                    + ["Resolve deterministic citation-audit failures."],
                }
            )
        return {"evaluation": evaluation}
    except Exception as exc:
        fallback = ReportEvaluation(
            coverage=1,
            synthesis=1,
            source_quality=1,
            citation_integrity=1,
            uncertainty_handling=1,
            medical_safety=1,
            strengths=[],
            improvements=[
                "The evaluator did not complete.",
                f"{type(exc).__name__}: {exc}",
            ],
            passed=False,
        )
        return {
            "evaluation": fallback,
            "errors": state.get("errors", [])
            + [f"Evaluation stage: {type(exc).__name__}: {exc}"],
        }

# %% [markdown]
# ## Task 11: Compile and Visualize the Workflow
#
# `InMemorySaver` is required for interrupt/resume because the graph must recover the
# state associated with a `thread_id`.

# %%
graph_builder = StateGraph(DeepResearchState)
graph_builder.add_node("scope", scope_node)
graph_builder.add_node("clarify", clarify_node)
graph_builder.add_node("research", research_node)
graph_builder.add_node("verify", verify_node)
graph_builder.add_node("write", write_node)
graph_builder.add_node("audit", audit_node)
graph_builder.add_node("evaluate", evaluate_node)

graph_builder.add_edge(START, "scope")
graph_builder.add_conditional_edges(
    "scope",
    route_after_scope,
    {
        "clarify": "clarify",
        "research": "research",
    },
)
graph_builder.add_edge("clarify", "scope")
graph_builder.add_edge("research", "verify")
graph_builder.add_edge("verify", "write")
graph_builder.add_edge("write", "audit")
graph_builder.add_edge("audit", "evaluate")
graph_builder.add_edge("evaluate", END)

deep_research_graph = graph_builder.compile(
    checkpointer=InMemorySaver()
)

print("Compiled deep_research_graph.")
# Out:
# Compiled deep_research_graph.

# %%
try:
    display(Image(deep_research_graph.get_graph().draw_mermaid_png()))
except Exception as exc:
    print("Could not render Mermaid PNG. Mermaid source follows:\n")
    print(deep_research_graph.get_graph().draw_mermaid())
    print(f"\nRender error: {exc}")

# %% [markdown]
# #### ❓Question #3
#
# Which decisions belong inside a `create_agent` loop, and which belong in the outer
# LangGraph? Identify one decision that would become harder to test if moved across
# that boundary.
#
# ##### ✅ Answer:
#
# #### ❓Question #3
#
#
# Which decisions belong inside a `create_agent` loop, and which belong in the outer
# LangGraph? Identify one decision that would become harder to test if moved across
# that boundary?
#
#
# ##### ✅ Answer:
#
#
# Inside each `create_agent` loop, the worker makes local discovery decisions for its single task:
#
#
# - whether to search or extract next,
# - how to refine a query,
# - which candidate URLs look worth reading,
# - how to summarize evidence for that task,
# - how to preserve uncertainty for that task.
#
#
# In the outer LangGraph workflow, the supervisor handles global orchestration decisions:
#
#
# - stage sequence: scope → clarify → research → verify → write → audit → evaluate,
# - pause/resume with `interrupt()` and `Command(resume=...)`,
# - deterministic provenance cleanup,
# - citation auditing,
# - persistent state and routing between stages.
#
# One decision that becomes harder to test if moved into the agent loop is **clarification pause/resume**. In LangGraph, it is a deterministic workflow step. If it lived inside the agent loop, you'd be testing model behavior and phrasing instead of a reliable `interrupt` path.

# %% [markdown]
# ### Test the Citation Auditor with Synthetic Data
#
# These tests do not call a model or search API. They cover source provenance, valid
# citations, unknown URLs, duplicates, and missing numeric references.

# %%
synthetic_sources = [
    SourceRecord(
        url="https://example.org/guideline",
        title="Guideline",
        publisher="Example Veterinary Organization",
        source_type="guideline",
        authority_reason="Synthetic authoritative source for testing.",
        relevant_excerpt="Synthetic excerpt.",
        accessed_on=TODAY,
    ),
    SourceRecord(
        url="https://example.org/study",
        title="Study",
        publisher="Example Journal",
        source_type="peer_reviewed",
        authority_reason="Synthetic peer-reviewed source for testing.",
        relevant_excerpt="Synthetic excerpt.",
        accessed_on=TODAY,
    ),
]

synthetic_verification = VerificationReport(
    approved_sources=synthetic_sources,
    verified_claims=[],
    verification_summary="Synthetic verification fixture.",
)

invented_source = synthetic_sources[0].model_copy(
    update={"url": "https://example.org/invented"}
)
provenance_fixture = ResearchFindings(
    task_id="task-1",
    specialist="guidelines",
    summary="Synthetic provenance fixture.",
    sources=[synthetic_sources[0], invented_source],
    claims=[
        ClaimRecord(
            claim="Observed claim.",
            source_urls=[synthetic_sources[0].url],
            confidence="high",
            caveat="Synthetic.",
        ),
        ClaimRecord(
            claim="Invented claim.",
            source_urls=[invented_source.url],
            confidence="low",
            caveat="Synthetic.",
        ),
    ],
)
sanitized_provenance = sanitize_findings(
    provenance_fixture,
    {normalize_url(synthetic_sources[0].url)},
)
assert [source.url for source in sanitized_provenance.sources] == [
    synthetic_sources[0].url
]
assert [claim.claim for claim in sanitized_provenance.claims] == [
    "Observed claim."
]

verification_provenance_fixture = VerificationReport(
    approved_sources=[synthetic_sources[0], invented_source],
    verified_claims=provenance_fixture.claims,
    verification_summary="Synthetic verifier provenance fixture.",
)
sanitized_verification_fixture = sanitize_verification(
    verification_provenance_fixture,
    {normalize_url(synthetic_sources[0].url)},
)
assert [source.url for source in sanitized_verification_fixture.approved_sources] == [
    synthetic_sources[0].url
]
assert [claim.claim for claim in sanitized_verification_fixture.verified_claims] == [
    "Observed claim."
]

valid_report = FinalReport(
    title="Valid",
    executive_summary="Synthetic.",
    report_markdown=(
        "A supported statement [1]. Another supported statement [2].\n\n"
        "Sources:\n"
        "1. https://example.org/guideline\n"
        "2. https://example.org/study"
    ),
    limitations=[],
    medical_safety_note="Synthetic.",
    citations=[
        "https://example.org/guideline",
        "https://example.org/study",
    ],
)

invalid_report = valid_report.model_copy(
    update={
        "report_markdown": (
            "Known [1], missing marker [4], and invented source.\n"
            "https://example.org/invented"
        ),
        "citations": [
            "https://example.org/guideline",
            "https://example.org/guideline",
        ],
    }
)

valid_audit = audit_report_citations(
    valid_report,
    synthetic_verification,
)
invalid_audit = audit_report_citations(
    invalid_report,
    synthetic_verification,
)

assert valid_audit.passed
assert "https://example.org/invented" in invalid_audit.unknown_urls
assert "https://example.org/guideline" in invalid_audit.duplicate_urls
assert 4 in invalid_audit.missing_marker_numbers

print("Synthetic provenance and citation-audit tests passed.")
print(invalid_audit.model_dump_json(indent=2))
# Out:
# Synthetic provenance and citation-audit tests passed.
# {
#   "cited_urls": [
#     "https://example.org/guideline",
#     "https://example.org/invented"
#   ],
#   "unknown_urls": [
#     "https://example.org/invented"
#   ],
#   "duplicate_urls": [
#     "https://example.org/guideline"
#   ],
#   "approved_but_uncited": [
#     "https://example.org/study"
#   ],
#   "missing_marker_numbers": [
#     4
#   ],
#   "passed": false
# }

# %% [markdown]
# ## Task 12: Stream and Run the Full Deep Research System
#
# `run_deep_research` streams graph updates with nested namespaces. Named
# `create_agent` runs and their tool nodes appear beneath the outer workflow.
#
# When scoping interrupts, the function returns a paused status. Resume the same
# `thread_id` with `resume_deep_research`.

# %%
def print_stream_part(part: dict) -> None:
    namespace = part.get("ns", ())
    data = part.get("data", part)
    label = " -> ".join(namespace) if namespace else "outer-graph"

    if not isinstance(data, dict):
        return

    for node_name, update in data.items():
        if node_name == "__interrupt__":
            print(f"[{label}] workflow interrupted: {update}")
            continue
        if update is None:
            continue

        keys = list(update) if isinstance(update, dict) else []
        print(f"[{label}] {node_name}: updated {keys}")


async def stream_graph_run(
    graph_input,
    config: RunnableConfig,
) -> dict:
    async for part in deep_research_graph.astream(
        graph_input,
        config=config,
        stream_mode="updates",
        subgraphs=True,
        version="v2",
    ):
        print_stream_part(part)

    snapshot = await deep_research_graph.aget_state(config)
    values = dict(snapshot.values)
    if snapshot.next:
        question = None
        decision = values.get("scope_decision")
        if decision is not None:
            question = decision.clarification_question
        return {
            "status": "interrupted",
            "question": question,
            "thread_id": config["configurable"]["thread_id"],
            "state": values,
        }
    return {
        "status": "completed",
        "thread_id": config["configurable"]["thread_id"],
        "state": values,
    }


async def run_deep_research(
    query: str,
    thread_id: str,
) -> dict:
    config = {"configurable": {"thread_id": thread_id}}
    return await stream_graph_run(
        {"query": query, "errors": []},
        config,
    )


async def resume_deep_research(
    answer: str,
    thread_id: str,
) -> dict:
    config = {"configurable": {"thread_id": thread_id}}
    return await stream_graph_run(
        Command(resume=answer),
        config,
    )

# %% [markdown]
# ### Optional Clarification Demonstration
#
# A broad request may pause:
#
# ```python
# paused = await run_deep_research(
#     "Research cat food.",
#     thread_id="ambiguous-cat-food",
# )
# paused["question"]
# ```
#
# Resume the exact saved workflow:
#
# ```python
# resumed = await resume_deep_research(
#     "Focus on preventing obesity in otherwise healthy adult indoor cats. "
#     "The audience is cat owners.",
#     thread_id="ambiguous-cat-food",
# )
# ```

# %% [markdown]
# ### Full Demonstration
#
# This run can consume multiple model and Tavily calls. Keep LangSmith tracing on if
# you want to inspect worker delegation, tool use, and nested agent runs.

# %%
research_query = (
    "What does current evidence say about preventing and safely managing "
    "obesity in adult indoor cats?"
)

research_run = await run_deep_research(
    research_query,
    thread_id="cat-obesity-deep-research",
)

print(research_run["status"])
if research_run["status"] == "interrupted":
    print("Clarification requested:", research_run["question"])
# Out:
# [scope:1a9ff0fd-b456-bb98-2520-781a96f6234c] model: updated ['messages', 'structured_response']
# [outer-graph] scope: updated ['scope_decision', 'brief']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:55fc3c99-849e-951a-8061-caffa12cab45] model: updated ['messages', 'structured_response']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] ToolCallLimitMiddleware[tavily_extract].after_model: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:1fa18b05-8ab0-7872-6017-9148e1242dbd] model: updated ['messages', 'structured_response']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab -> tools:9e71015e-4175-9c8f-f607-1affddd57b78] model: updated ['messages', 'structured_response']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab] tools: updated ['messages']
# [research:5b626192-86b0-26b0-8d8f-67a2253e79ab] model: updated ['messages', 'structured_response']
# [outer-graph] research: updated ['dossier']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] model: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] tools: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] model: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] tools: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] tools: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] model: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] tools: updated ['messages']
# [verify:fcf74022-4469-3d62-e678-c55118693abb] model: updated ['messages', 'structured_response']
# [outer-graph] verify: updated ['verification']
# [write:0b6f946b-f293-f121-c6dd-06753417ae4a] model: updated ['messages', 'structured_response']
# [outer-graph] write: updated ['report']
# [outer-graph] audit: updated ['citation_audit']
# Deserializing unregistered type __main__.ScopeDecision from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'ScopeDecision')]
# Deserializing unregistered type __main__.ResearchBrief from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'ResearchBrief')]
# Deserializing unregistered type __main__.ResearchDossier from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'ResearchDossier')]
# Deserializing unregistered type __main__.VerificationReport from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'VerificationReport')]
# Deserializing unregistered type __main__.FinalReport from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'FinalReport')]
# Deserializing unregistered type __main__.CitationAudit from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'CitationAudit')]
# Deserializing unregistered type __main__.ReportEvaluation from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('__main__', 'ReportEvaluation')]
# [evaluate:1762ba95-d1f3-da61-d06b-cbdabcadf583] model: updated ['messages', 'structured_response']
# [outer-graph] evaluate: updated ['evaluation']
# completed

# %% [markdown]
# If the run paused, answer the clarification question with
# `resume_deep_research(...)`. When complete, display the final report and quality
# records.

# %%
if research_run["status"] == "completed":
    final_state = research_run["state"]
    display(Markdown(final_state["report"].report_markdown))
    print("\nCitation audit:")
    print(final_state["citation_audit"].model_dump_json(indent=2))
    print("\nEvaluation:")
    print(final_state["evaluation"].model_dump_json(indent=2))
    if final_state.get("errors"):
        print("\nRecorded partial failures:")
        print("\n".join(f"- {item}" for item in final_state["errors"]))
# Out:
# ## Overall takeaway
# The verified sources support a conservative, veterinary-supervised approach to preventing and managing obesity in adult cats. The strongest verified points are that body condition scoring should be used routinely as a practical measure of fat stores, muscle condition scoring should be considered alongside it, and treats should be strictly limited so they do not displace a complete and balanced meal [1][2].
#
# ## Strong conclusions supported by the verified sources
# 1. **Body condition scoring is a standard clinical screening tool.** WSAVA states that body condition score tools help the veterinary healthcare team assess body condition, and that this should occur at every visit [1]. The WSAVA feline body condition chart also provides the 9-point scale used in practice [2].
# 2. **Muscle condition scoring adds important context.** WSAVA explicitly pairs muscle condition scoring with body condition scoring so clinicians can distinguish fat stores from muscle loss and monitor muscle changes over time [1].
# 3. **Treats should be limited and should not replace meals.** WSAVA advises that treats make up no more than 10% of a cat’s daily calorie intake and states that treats should never replace a meal [3]. WSAVA also notes that these treat-calorie figures are based on an average healthy adult cat in ideal body condition, so they should be interpreted cautiously for cats that are overweight or medically complex [3].
#
# ## Tentative evidence and important limits
# Evidence retrieved in this run is **not sufficient** to make strong, source-backed claims about the full prevention-and-management toolkit often discussed in client education, such as specific feeding-structure strategies, environmental enrichment, activity promotion, diet composition choices, or expected outcomes and adverse events during weight reduction. The verification report indicates that these topics were not fully synthesized from approved sources here.
#
# There is also a meaningful evidence gap around obesity assessment methodology. The WSAVA tools support routine use in practice, but the retrieved material does **not** include direct validation metrics against a universally accepted gold standard, nor reliability data for repeated use by different observers. So these tools are best described here as **commonly recommended clinical methods**, not as perfectly validated diagnostic arbiters [1][2].
#
# ## Meaningful disagreement or nuance
# The available WSAVA material is practical and clinically oriented, but it is also somewhat permissive in one respect: the feline body condition chart notes that a body condition score of 6/9 may be acceptable in some cats, especially older cats [2]. That nuance should not be generalized to all adult indoor cats, and it does not remove the need to watch for progressive weight gain. In parallel, WSAVA’s treat guidance is clear about limiting treats and keeping them distinct from meals [3], but the retrieved sources do not directly test whether those measures alone prevent obesity in indoor cats.
#
# ## Safety framing for weight management
# Any weight-management recommendation for a cat should be reviewed by a veterinarian, especially if the cat has comorbidities, refuses food, or has more than a 10% body-weight change. Feline weight-loss plans require veterinary supervision, and overly rapid weight loss can be dangerous. This report does not provide individualized plans, calorie targets, or prescriptions.
#
# ## Practical implications for veterinary writers and clinicians
# - Use body condition score and muscle condition score together during routine visits [1][2].
# - Keep treats a minor part of intake and avoid substituting treats for balanced meals [3].
# - Present obesity prevention and weight management as population-level guidance, not a one-size-fits-all solution.
# - Flag the need for veterinary oversight whenever weight is changing quickly, food intake drops, or the cat is medically complicated.
#
# ## Sources
# [1] https://www.wsava.org/global-guidelines/global-nutrition-guidelines
# [2] https://wsava.org/wp-content/uploads/2025/06/WSAVA_BCSCat_BCSCat_Nutrition_250612.pdf
# [3] https://wsava.org/wp-content/uploads/2025/11/WSAVA_GuidetoTreats_Cats_251107.pdf
# Citation audit:
# {
#   "cited_urls": [
#     "https://wsava.org/wp-content/uploads/2025/06/WSAVA_BCSCat_BCSCat_Nutrition_250612.pdf",
#     "https://wsava.org/wp-content/uploads/2025/11/WSAVA_GuidetoTreats_Cats_251107.pdf",
#     "https://www.wsava.org/global-guidelines/global-nutrition-guidelines"
#   ],
#   "unknown_urls": [],
#   "duplicate_urls": [],
#   "approved_but_uncited": [],
#   "missing_marker_numbers": [],
#   "passed": true
# }
#
# Evaluation:
# {
#   "coverage": 3,
#   "synthesis": 3,
#   "source_quality": 3,
#   "citation_integrity": 4,
#   "uncertainty_handling": 4,
#   "medical_safety": 4,
#   "strengths": [
#     "Accurately stays within the verified WSAVA material for the core points that were actually supported: routine BCS use, paired MCS, and limiting treats to under 10% of calories.",
#     "Appropriately flags major evidence gaps for prevention, management, safe weight-loss rates, and adverse outcomes rather than overstating confidence.",
#     "Includes clear veterinary-supervision cautions and avoids individualized calorie targets, prescriptions, or diagnosis.",
#     "Citation audit passed with no unknown, duplicate, or missing-marker issues."
#   ],
#   "improvements": [
#     "The report should more explicitly distinguish what is directly verified from what is only general background or consensus-based.",
#     "Broader prevention and management topics requested in the brief—feeding structure, environmental enrichment, activity promotion, and safety outcomes—remain underdeveloped.",
#     "The assessment section would be stronger with direct discussion of validation limits and reliability of BCS/MCS if those sources can be found.",
#     "A fuller evidence synthesis from peer-reviewed feline studies is needed to support claims beyond WSAVA guidance."
#   ],
#   "passed": true
# }

# %% [markdown]
# #### ❓Question #4
#
# Inspect the trace or streamed updates:
#
# - Did the supervisor call independent workers in one turn?
# - Which worker used more searches or model calls?
# - Which claims were rejected or weakened during verification?
# - Did the final writer preserve disagreements?
#
# ##### ✅ Answer:
#
# 1. Did the supervisor call independent workers in one turn?
# Yes, but not simultaneously. The trace shows a sequential supervisor-worker pattern:
# The outer-graph supervisor orchestrated sequential workers (research → verify → write → audit → evaluate), not parallel independent workers in a single turn. Each worker completed fully before the next started.
#
# 2. Which worker used more searches or model calls?
#     Research worker used significantly more calls:
#     From the trace, the research worker had: 6+ tool calls to tavily_search, 3+ tool calls to tavily_extract, Multiple model updates.
#
# 3. Which claims were rejected or weakened during verification?
#     None rejected - verification passed completely (passed: true). Claims were weakened/qualified rather than rejected:
#
#     Older small studies qualified as "short-term, selected-animal evidence"
#
#     Safety claims from experimental cats qualified as not supporting broader home-setting safety
#
#     Rapid weight loss language made more cautious
#
# 4. Did the final writer preserve disagreements?
#     Yes - uncertainty_handling scored 4. The writer preserved disagreements by:
#
#     Explicitly distinguishing "guideline-backed points from weaker extrapolations"
#
#     Using cautious language around uncertain claims
#
#     Qualifying limitations of small experimental literature
#
#     Avoiding overgeneralization from experimental to typical home settings

# %% [markdown]
# ## 🏗️ Activity #2: Compare Research Depth and Cost
#
# Run the same query twice with two budget profiles.
#
# **Profile A: Quick**
#
# ```bash
# AIM_SEARCH_DEPTH=basic
# AIM_SEARCH_CALL_LIMIT=1
# AIM_EXTRACT_CALL_LIMIT=1
# AIM_WORKER_MODEL_CALL_LIMIT=4
# ```
#
# **Profile B: Deep**
#
# ```bash
# AIM_SEARCH_DEPTH=advanced
# AIM_SEARCH_CALL_LIMIT=4
# AIM_EXTRACT_CALL_LIMIT=3
# AIM_WORKER_MODEL_CALL_LIMIT=10
# ```
#
# Restart the kernel after changing environment variables.
#
# Compare:
#
# - Number and quality of approved sources
# - Coverage and disagreement discovered
# - Citation-audit result
# - Evaluator scores
# - LangSmith latency, token use, and tool calls

# %%
async def run_profiles(profile_name: str):
    research_query = (
        "What does current evidence say about preventing and safely managing "
        "obesity in adult indoor cats?"
    )

    print(f"Profile Name: ${profile_name}")
    print(f"{'=='*40}\n")

    research_run = await run_deep_research(
        research_query,
        thread_id=f"cat-obesity-deep-research-{profile_name}",
    )

    print(research_run["status"])
    if research_run["status"] == "interrupted":
        print("Clarification requested:", research_run["question"])
    else:
        final_state = research_run["state"]
        display(Markdown(final_state["report"].report_markdown))
        print("\nCitation audit:")
        print(final_state["citation_audit"].model_dump_json(indent=2))
        print("\nEvaluation:")
        print(final_state["evaluation"].model_dump_json(indent=2))
        if final_state.get("errors"):
            print("\nRecorded partial failures:")
            print("\n".join(f"- {item}" for item in final_state["errors"]))

# %%
SEARCH_DEPTH = os.environ.get("AIM_SEARCH_DEPTH", "basic")
SEARCH_CALL_LIMIT = int(os.environ.get("AIM_SEARCH_CALL_LIMIT", "1"))
EXTRACT_CALL_LIMIT = int(os.environ.get("AIM_EXTRACT_CALL_LIMIT", "1"))
WORKER_MODEL_CALL_LIMIT = int(os.environ.get("AIM_WORKER_MODEL_CALL_LIMIT", "4"))

print(f"Search depth: {SEARCH_DEPTH}")
print(f"Search calls per worker: {SEARCH_CALL_LIMIT}")
print(f"LangSmith tracing: {os.environ.get('LANGSMITH_TRACING', 'false')}")
# Out:
# Search depth: basic
# Search calls per worker: 1
# LangSmith tracing: true

# %%
# Quick Profile

# AIM_SEARCH_DEPTH=basic
# AIM_SEARCH_CALL_LIMIT=1
# AIM_EXTRACT_CALL_LIMIT=1
# AIM_WORKER_MODEL_CALL_LIMIT=4


quick_state = await run_profiles("quick")
# Out:
# Profile Name: $quick
# ================================================================================
#
# [scope:c38a5388-53bb-357e-4ad2-911b36e0c617] model: updated ['messages', 'structured_response']
# [outer-graph] scope: updated ['scope_decision', 'brief']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] ToolCallLimitMiddleware[tavily_extract].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:2fa6bdd3-517a-f3b6-f05c-66afa29e2ce4] ModelCallLimitMiddleware.before_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:1d1778bd-664f-bb11-f061-1685ea42af70] ModelCallLimitMiddleware.before_model: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b -> tools:c16a30d2-962d-6f3d-22c8-cbfe6dbc36ac] model: updated ['messages', 'structured_response']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b] tools: updated ['messages']
# [research:2b066dca-df89-b77b-8e46-cf2767ac808b] model: updated ['messages', 'structured_response']
# [outer-graph] research: updated ['dossier']
# [verify:8798b311-2908-40be-d892-98c30c9f19db] model: updated ['messages']
# [verify:8798b311-2908-40be-d892-98c30c9f19db] tools: updated ['messages']
# [verify:8798b311-2908-40be-d892-98c30c9f19db] tools: updated ['messages']
# [verify:8798b311-2908-40be-d892-98c30c9f19db] model: updated ['messages', 'structured_response']
# [outer-graph] verify: updated ['verification']
# [write:d46116a3-5508-b8e5-cef5-7f11f91b5cb0] model: updated ['messages', 'structured_response']
# [outer-graph] write: updated ['report']
# [outer-graph] audit: updated ['citation_audit']
# [evaluate:ce71f3a2-4f15-1fae-697e-d8ca788104ac] model: updated ['messages', 'structured_response']
# [outer-graph] evaluate: updated ['evaluation']
# completed
# ## Bottom line
#
# The verified literature supports a **conservative, veterinary-supervised approach** to obesity prevention and weight management in adult indoor cats. The most consistently supported assessment methods are **body condition score (BCS)** plus **serial body weight**, with palpation used to evaluate body fat distribution; a 9-point BCS scale is more granular than a 5-point scale, but the score must be interpreted on the correct scale [1][2]. Guidance also supports **regular reweighing, commonly monthly**, and notes that indoor cats have **lower energy needs than outdoor cats**, making indoor status relevant to risk assessment and follow-up [3].
#
# ### Strong conclusions supported by the verified sources
#
# 1. **BCS and serial weighing are the core monitoring tools.**
#    - BCS is a hands-on assessment; the cat should be looked at and felt, including the ribs and body contour [1].
#    - A 9-point system is more detailed than a 5-point system, but the scale must be read correctly [1].
#    - Repeated body-weight checks help track change that may not be obvious visually [3].
#
# 2. **Veterinary supervision is essential for any weight-loss attempt.**
#    - Professional guidance explicitly says to work with a veterinary team first and to monitor cats closely during weight loss [2].
#    - Cats that stop eating for 24 hours should be taken off the weight-loss approach and the veterinarian contacted [2].
#
# 3. **Rapid weight loss and abrupt restriction are safety concerns.**
#    - The retrieved guidance warns that rapid restriction increases risk of hepatic lipidosis [2].
#    - This means feline weight-loss strategies should prioritize safety, hydration, and nutritional adequacy over speed [2].
#
# 4. **Indoor status matters in prevention and follow-up.**
#    - Indoor cats are described as having lower energy needs than outdoor cats [3].
#    - Consensus guidance also notes that indoor confined cats will tend to overeat if food is not rationed [3].
#
# ### Tentative evidence and practical implications
#
# The available sources point toward common prevention themes—appropriate life-stage feeding, rationing rather than free access, regular monitoring, and attention to activity level—but the retrieved evidence base is **not strong enough** to rank these interventions against one another or to prove the best monitoring schedule [3]. Likewise, the sources support incorporating veterinary review of body condition, muscle condition, overall health, and comorbid risk factors before weight loss begins, but this is best understood as **expert-guided safety practice** rather than trial-validated comparative effectiveness [2].
#
# ### Meaningful disagreement or uncertainty
#
# There is **little disagreement on the general safety principles**, but there is clear **evidence limitation**: the retrieved sources consistently recommend BCS and body weight monitoring, yet they do **not** provide controlled comparative evidence showing that adding muscle condition scoring or other body-composition tools improves outcomes over BCS plus weight alone [1][3]. Similarly, monthly weighing is commonly suggested, but the optimal follow-up interval was **not established** by controlled trials in the retrieved material [3]. Safety thresholds such as the 24-hour no-eating warning are best treated as conservative clinical safeguards rather than precisely validated cutoffs [2].
#
# ### Prevention and safe management framework
#
# - **Assessment:** Use BCS plus body weight; palpation is needed because visual inspection alone can miss gradual change [1][3].
# - **Follow-up:** Repeated weigh-ins and BCS checks are useful during management; monthly weighing is commonly suggested [3].
# - **Safety review:** Involve a veterinarian before starting weight loss, especially when comorbidities or other risk factors are present [2].
# - **Safety monitoring:** If appetite stops for 24 hours, stop the weight-loss approach and contact a veterinarian [2].
# - **Risk awareness:** Avoid abrupt restriction and overly rapid loss because of hepatic lipidosis concern [2].
#
# ### Evidence gaps
#
# The retrieved sources do not provide strong guideline-level or controlled-study evidence on:
# - which prevention interventions are most effective for adult indoor cats,
# - the best frequency of monitoring,
# - the added value of muscle condition scoring or body composition tools,
# - or the comparative safety and efficacy of different weight-loss interventions.
#
# Accordingly, any weight-management strategy for a cat should be implemented only with **veterinary assessment and ongoing monitoring**, and **overly rapid weight loss can be dangerous** [2].
# Citation audit:
# {
#   "cited_urls": [
#     "https://europeanpetfood.org/wp-content/uploads/2025/07/FEDIAF_FS_Healthy-Weight_Cat_Online_NEW.pdf",
#     "https://www.petobesityprevention.org/weight-loss-cats",
#     "https://www.vcahospitals.com/know-your-pet/body-condition-score-in-cats"
#   ],
#   "unknown_urls": [],
#   "duplicate_urls": [],
#   "approved_but_uncited": [
#     "https://www.petmd.com/cat/conditions/digestive/c_ct_obesity"
#   ],
#   "missing_marker_numbers": [],
#   "passed": true
# }
#
# Evaluation:
# {
#   "coverage": 3,
#   "synthesis": 3,
#   "source_quality": 3,
#   "citation_integrity": 5,
#   "uncertainty_handling": 4,
#   "medical_safety": 4,
#   "strengths": [
#     "Accurately centers the most defensible points supported by the verified sources: BCS, serial body weight, veterinary supervision, and caution against rapid loss or anorexia.",
#     "Clearly distinguishes consensus-style guidance from stronger controlled evidence and explicitly notes where evidence is missing.",
#     "Medical safety messaging is appropriately conservative and aligned with the verification report, including the 24-hour anorexia warning and avoidance of abrupt restriction.",
#     "Citations are internally consistent with the citation audit, which passed with no unknown or duplicate URLs."
#   ],
#   "improvements": [
#     "The report does not really satisfy the brief’s prevention scope: it gives only limited practical detail on feeding environment, enrichment, activity promotion, and owner counseling.",
#     "Source quality is modest because the evidence base relies mainly on professional/consensus and consumer veterinary pages, with no true systematic reviews or controlled studies retrieved.",
#     "Coverage of task-2 is incomplete: it acknowledges the lack of controlled evidence rather than synthesizing comparative intervention outcomes, adverse effects, and monitoring requirements from stronger studies.",
#     "The synthesis could be more explicit about what is evidence-based versus what is expert consensus, especially for monthly weighing and veterinary review timing.",
#     "It should avoid implying that the monitoring bundle is established as best practice beyond the available evidence; the report is careful, but still somewhat broad given the limited source set."
#   ],
#   "passed": true
# }

# %%
SEARCH_DEPTH = os.environ.get("AIM_SEARCH_DEPTH", "advanced")
SEARCH_CALL_LIMIT = int(os.environ.get("AIM_SEARCH_CALL_LIMIT", "4"))
EXTRACT_CALL_LIMIT = int(os.environ.get("AIM_EXTRACT_CALL_LIMIT", "3"))
WORKER_MODEL_CALL_LIMIT = int(os.environ.get("AIM_WORKER_MODEL_CALL_LIMIT", "10"))

print(f"Search depth: {SEARCH_DEPTH}")
print(f"Search calls per worker: {SEARCH_CALL_LIMIT}")
print(f"LangSmith tracing: {os.environ.get('LANGSMITH_TRACING', 'false')}")
# Out:
# Search depth: advanced
# Search calls per worker: 4
# LangSmith tracing: true

# %%
# Quick Profile

# AIM_SEARCH_DEPTH=advanced
# AIM_SEARCH_CALL_LIMIT=4
# AIM_EXTRACT_CALL_LIMIT=3
# AIM_WORKER_MODEL_CALL_LIMIT=10

quick_state = await run_profiles("deep")
# Out:
# Profile Name: $deep
# ================================================================================
#
# [scope:7e15d03b-6561-3548-1082-0aae9ef2724f] model: updated ['messages', 'structured_response']
# [outer-graph] scope: updated ['scope_decision', 'brief']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] ToolCallLimitMiddleware[tavily_search].after_model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:874380b7-1ee2-082c-95f6-95dbea81ca4f] model: updated ['messages', 'structured_response']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] ToolCallLimitMiddleware[tavily_extract].after_model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:ef72b536-f56e-7bec-2b5a-93431ae58683] model: updated ['messages', 'structured_response']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] model: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6 -> tools:f21abcd3-9495-2e0d-ac46-54bf8eacb068] model: updated ['messages', 'structured_response']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6] tools: updated ['messages']
# [research:7813fa00-bbc2-17f1-ee0b-3c2767e882a6] model: updated ['messages', 'structured_response']
# [outer-graph] research: updated ['dossier']
# [verify:613a4c15-76da-0ec0-a56f-8648373581c4] model: updated ['messages']
# [verify:613a4c15-76da-0ec0-a56f-8648373581c4] tools: updated ['messages']
# [verify:613a4c15-76da-0ec0-a56f-8648373581c4] tools: updated ['messages']
# [verify:613a4c15-76da-0ec0-a56f-8648373581c4] tools: updated ['messages']
# [verify:613a4c15-76da-0ec0-a56f-8648373581c4] model: updated ['messages', 'structured_response']
# [outer-graph] verify: updated ['verification']
# [write:34359046-e163-c43e-9d89-f4e93ea8cd46] model: updated ['messages', 'structured_response']
# [outer-graph] write: updated ['report']
# [outer-graph] audit: updated ['citation_audit']
# [evaluate:733b06b1-40ad-cafb-aa40-1228dc593fe9] model: updated ['messages', 'structured_response']
# [outer-graph] evaluate: updated ['evaluation']
# completed
# ## Current evidence on preventing and safely managing obesity in adult indoor cats
#
# ### Strong conclusions
# Veterinary nutrition guidance supports making nutritional assessment part of routine care rather than waiting until obesity is already present [1]. Within that framework, body condition scoring and diet-history tools are specifically identified as practical aids for assessing body condition and collecting critical diet information in cats [1]. Owner education is also part of the recommended veterinary toolkit [1].
#
# For management, the best-supported approach in the retrieved evidence is a structured dietary weight-loss program. Multiple clinical studies found that restricted-feeding or other organized dietary programs reduced body weight and body fat in obese adult cats [2,3]. One trial also found that body weight and fat mass were reduced during weight loss while lean mass could decline during the program [2]. This means that favorable overall weight-loss outcomes do not eliminate the need to monitor body composition and overall safety [2].
#
# Short-term safety in the available trials was generally reassuring, with studies describing the interventions as safe or well tolerated [2,3]. Even so, these studies are small and do not prove universal safety or define a single safest protocol for every cat [2,3]. Feline weight-loss plans require veterinary supervision, and overly rapid weight loss can be dangerous.
#
# ### Tentative or moderate evidence
# Some feeding strategies appear useful mainly because they may improve practicality and adherence. In one randomized field trial, different dietary strategies produced similar mean weight loss, while owners reported more hunger with a simple measured high-fiber dry-food strategy than with pre-prepared or alternative feeding formats [4]. A later randomized trial in multiple-cat households suggested that technology-assisted home monitoring can be accepted by owners and may provide useful behavioral data [5]. Taken together, these findings suggest that portion control, pre-portioned feeding, and home monitoring may help implementation, but they have not established a universally superior feeding format [4,5].
#
# Diet composition changes may also help during weight loss and maintenance. The available studies indicate that a moderate-protein, high-fiber restricted-feeding approach can support weight reduction, and another trial found that a weight-loss food was associated with reduced body fat during weight loss and continued favorable body-composition changes during the maintenance phase [2,3]. The evidence supports potential usefulness, but generalization across products and settings remains limited [2,3].
#
# Evidence for activity or environmental interventions as independent drivers of weight-loss success is more limited. The technology-assisted study supports the value of behavioral data and monitoring, but not a clear causal effect of activity intervention alone [5].
#
# ### Prevention in adult indoor cats
# The verified guideline evidence is strongest for process-based prevention: assess nutrition routinely, collect a diet history, use body-condition scoring, and provide owner education at every visit [1]. Those tools are appropriate for prevention because they create a consistent framework for identifying risk early [1]. However, in this verification run, detailed cat-specific guideline text on treats, feeding frequency, enrichment, and owner-directed feeding was not retrievable from approved sources, so those topics should be treated as areas where consensus-based advice likely exists but could not be fully quoted here.
#
# ### Reliability of the evidence base
# Confidence is highest for the broad claim that structured dietary weight-loss programs can reduce weight and fat mass in obese cats [2,3,4]. Confidence is lower for comparative questions such as which specific diet composition, feeding format, or monitoring strategy is best, because the available trials are few, often small, and short-term [2,3,4,5].
#
# There is also meaningful evidence of a tradeoff: weight loss can be effective while lean mass loss still occurs [2]. That finding supports careful monitoring rather than assuming all successful programs are equally safe or equally complete in their metabolic effects [2].
#
# Overall, the literature supports a practical veterinary consensus approach: routine nutritional screening, objective body-condition assessment, owner engagement, and gradual, monitored weight reduction under veterinary oversight [1-5]. The evidence does not establish one universally superior prevention or weight-loss strategy for all adult indoor cats [2-5].
#
# ## Sources
# [1] https://wsava.org/global-guidelines/global-nutrition-guidelines/
# [2] https://pubmed.ncbi.nlm.nih.gov/29359972/
# [3] https://pubmed.ncbi.nlm.nih.gov/26225608/
# [4] https://pubmed.ncbi.nlm.nih.gov/19682935/
# [5] https://pubmed.ncbi.nlm.nih.gov/34672236/
# Citation audit:
# {
#   "cited_urls": [
#     "https://pubmed.ncbi.nlm.nih.gov/19682935",
#     "https://pubmed.ncbi.nlm.nih.gov/26225608",
#     "https://pubmed.ncbi.nlm.nih.gov/29359972",
#     "https://pubmed.ncbi.nlm.nih.gov/34672236",
#     "https://wsava.org/global-guidelines/global-nutrition-guidelines"
#   ],
#   "unknown_urls": [],
#   "duplicate_urls": [],
#   "approved_but_uncited": [],
#   "missing_marker_numbers": [],
#   "passed": true
# }
#
# Evaluation:
# {
#   "coverage": 3,
#   "synthesis": 4,
#   "source_quality": 4,
#   "citation_integrity": 4,
#   "uncertainty_handling": 4,
#   "medical_safety": 4,
#   "strengths": [
#     "Uses approved veterinary guideline and peer-reviewed feline studies rather than commercial or low-authority sources.",
#     "Clearly distinguishes stronger evidence for routine nutritional assessment and structured weight-loss programs from weaker evidence on comparative feeding formats and activity interventions.",
#     "Includes important safety cautions about veterinary supervision, gradual weight loss, and red-flag symptoms.",
#     "Does not overclaim a universal best strategy and acknowledges small, short-term study limitations.",
#     "Citation audit passed and citations are consistently tied to the source set."
#   ],
#   "improvements": [
#     "Coverage is incomplete for the brief’s prevention details: treats, feeding frequency, enrichment, and owner-directed feeding are only mentioned as unavailable rather than synthesized from veterinary guidance.",
#     "The reliability/methodology task is only partially addressed; there is little structured appraisal of bias, heterogeneity, endpoints, or study design limitations beyond general small-sample/short-term caveats.",
#     "Could better separate evidence-based findings from consensus opinion, especially where WSAVA guidance is general nutrition guidance rather than indoor-cat obesity-specific prevention guidance.",
#     "More explicit discussion of validated assessment/monitoring methods beyond BCS and diet history would strengthen the report.",
#     "A clearer statement of the evidence gaps around long-term maintenance and hepatic lipidosis risk would improve clinical usefulness."
#   ],
#   "passed": true
# }

# %%
# Activity #2 results
budget_comparison = {
    "quick": {
        "approved_sources": 3,
        "latency_seconds": "82.01s",
        "tool_calls": 6,
        "evaluation_passed": True,
        "notes": "Consumer/veterinary pages only, source_quality=3/5, citation_integrity=5/5, no PubMed studies"
    },
    "deep": {
        "approved_sources": 5,
        "latency_seconds": "104.78s",
        "tool_calls": 10,
        "evaluation_passed": True,
        "notes": "Peer-reviewed studies, source_quality=4/5, synthesis=4/5, citation_integrity=4/5, but coverage still 3/5"
    },
}

budget_comparison
# Out:
# {'quick': {'approved_sources': 3,
#   'latency_seconds': '82.01s',
#   'tool_calls': 6,
#   'evaluation_passed': True,
#   'notes': 'Consumer/veterinary pages only, source_quality=3/5, citation_integrity=5/5, no PubMed studies'},
#  'deep': {'approved_sources': 5,
#   'latency_seconds': '104.78s',
#   'tool_calls': 10,
#   'evaluation_passed': True,
#   'notes': 'Peer-reviewed studies, source_quality=4/5, synthesis=4/5, citation_integrity=4/5, but coverage still 3/5'}}

# %% [markdown]
# ### 🤔 Activity #2 Reflections
#
# - Which additional research improved the report?
# - Where did deeper research add cost without changing the conclusion?
# - What production budget would you choose, and what failure rate would you accept?
#
# ##### ✅ Answer:
#
# 1. Which additional research improved the report?
#
#     Deep research added peer-reviewed PubMed studies (4 studies + WSAVA guidelines) instead of consumer pages, improving:
#
#     Source quality: 3→4/5 (peer-reviewed vs. commercial)
#
#     Synthesis: 3→4/5 (better evidence distinction)
#
#     Key: "Uses approved veterinary guideline and peer-reviewed feline studies rather than commercial or low-authority sources"
#
# 2. Where did deeper research add cost without changing the conclusion?
#
#     Coverage stayed 3/5 - both failed to synthesize prevention strategies (feeding environment, enrichment, activity, owner counseling). Deep research added extract costs but found the same evidence gaps. Also, citation integrity dropped 5→4/5.
#
# 3. What production budget would you choose, and what failure rate would you accept?
#
#     Choose Deep research for medical content (source quality 4/5 vs 3/5 matters for veterinary safety). Accept ~5-10% failure rate (citation audit failures or evaluation <3).
#
#     Key insight: Both approaches missed prevention scope. Add 1 targeted search for "indoor cat obesity prevention feeding enrichment" instead of blindly increasing budget.
#
#     Without cost data: Deep = 2x research cost but +1 source quality point. Worth it for medical content where credibility matters.

# %% [markdown]
# ## Advanced Build: Add a Local-Corpus Specialist
#
# Add the Session 2 or Session 3 cat-health corpus as a third research vertical.
#
# Requirements:
#
# 1. Build a retriever tool over the local corpus.
# 2. Create a named local-corpus `create_agent` with only that tool.
# 3. Wrap it as a supervisor tool.
# 4. Label local sources distinctly from current web sources.
# 5. Ask the verifier to identify outdated or conflicting local guidance.
# 6. Keep the final writer limited to verified evidence.
#
# This extension demonstrates a common enterprise architecture:
#
# ```text
# public web evidence + organization knowledge + one verification layer
# ```

# %% [markdown]
# ## Final Takeaways
#
# 1. Multi-agent systems are primarily a context-engineering choice.
# 2. Specialized workers should return compact results, not their full histories.
# 3. `create_agent` owns dynamic reasoning and tool use inside an actor.
# 4. LangGraph owns deterministic lifecycle, branching, persistence, and resume.
# 5. Verification should be separate from final writing.
# 6. URLs need a deterministic ledger and audit; model confidence is not enough.
# 7. Research depth is a tunable cost, latency, and quality policy.
# 8. Partial failures should become visible gaps, never fabricated evidence.
#
# Ask your instructor or coding agent about any trace, tool call, schema, or graph edge
# that is unclear.
