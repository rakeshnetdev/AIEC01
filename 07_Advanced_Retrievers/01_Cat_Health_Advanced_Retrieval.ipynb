# %% [markdown]
# # Advanced Retrieval with the Cat Health PDF
#
# Session 1 used a dense vector retriever:
#
# ```text
# question -> embed -> nearest chunks -> answer
# ```
#
# This notebook keeps the same cat-health PDF and compares dense vector search, BM25, parent-child retrieval, hybrid retrieval, Cohere reranking, and multi-query retrieval.
#
# > This is a retrieval exercise, not veterinary guidance. Answer only from retrieved context. Recommend a veterinarian for diagnosis, treatment, medication, or urgent-care decisions.

# %% [markdown]
# ## Learning Outcomes
#
# By the end of this session, you will be able to:
#
# - Explain the different failure modes of dense and BM25 retrieval.
# - Fuse independent ranked lists with reciprocal rank fusion (RRF).
# - Increase recall with multiple generated search queries.
# - Search focused child chunks while returning useful parent-page context.
# - Use Cohere Rerank as a second-stage ranker.
# - Compare retrieval systems with reviewed cases, visible evidence, metrics, and latency.

# %% [markdown]
# ## Build Order
#
# Build and compare the following layers:
#
# 1. Naive dense RAG: in-memory Qdrant, OpenAI embeddings, nearest child chunks, and a grounded answer.
# 2. BM25: sparse lexical retrieval over the same chunks.
# 3. Parent-child retrieval: search precise child chunks and return their parent PDF pages.
# 4. Hybrid retrieval with Cohere reranking: fuse dense and BM25 candidates with reciprocal rank fusion (RRF), recover parent pages, then rerank them.
# 5. Multi-query retrieval: generate alternate searches before the hybrid retrieve-then-rerank pipeline.
#
# Dense retrieval plus BM25 is **hybrid retrieval** (or hybrid search). RRF is an **ensemble** method that combines their ranked lists. Adding Cohere reranking creates a **two-stage hybrid retrieve-then-rerank pipeline**.
#
# Extra stages add latency, cost, and sometimes noise. Evaluate each added stage against those trade-offs.

# %% [markdown]
# ## Task 1: Setup
#
# Install the project environment from the session folder with `uv sync`, then run this notebook from that same folder. You need `OPENAI_API_KEY` and `COHERE_API_KEY` available when the notebook prompts for them.

# %%
from __future__ import annotations

import os
import re
from dataclasses import replace
from getpass import getpass
from pathlib import Path
from typing import Iterable, Sequence

import pandas as pd
from langchain_cohere import CohereRerank
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from rank_bm25 import BM25Okapi

from lib import (
    AnswerOutput,
    EvalCase,
    EvalItem,
    RetrievedDocument,
    answer_similarity_scorer,
    compare_eval_reports,
    compare_reports,
    faithfulness_scorer,
    make_openai_faithfulness_judge,
    run_eval,
    run_retrieval_eval,
)
# Out:
# /var/folders/0g/5xtfgw415q7cbj_fd_g3yk2h0000gn/T/ipykernel_37342/2795770623.py:12: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")

if not os.environ.get("COHERE_API_KEY"):
    os.environ["COHERE_API_KEY"] = getpass("Cohere API Key: ")

CHAT_MODEL = os.environ.get("AIM_CHAT_MODEL", "gpt-5.4-mini")
EVAL_MODEL = os.environ.get("AIM_EVAL_MODEL", CHAT_MODEL)
EMBEDDING_MODEL = os.environ.get("AIM_EMBEDDING_MODEL", "text-embedding-3-small")
RERANK_MODEL = os.environ.get("AIM_RERANK_MODEL", "rerank-v4.0-fast")

embeddings = OpenAIEmbeddings(model=EMBEDDING_MODEL)
answer_model = ChatOpenAI(model=CHAT_MODEL, temperature=0)
evaluation_model = ChatOpenAI(model=EVAL_MODEL, temperature=0)
query_model = ChatOpenAI(model=CHAT_MODEL, temperature=0)

print(f"Chat model: {CHAT_MODEL}")
print(f"Evaluation model: {EVAL_MODEL}")
print(f"Embedding model: {EMBEDDING_MODEL}")
print(f"Cohere rerank model: {RERANK_MODEL}")
# Out:
# Chat model: gpt-5.4-mini
# Evaluation model: gpt-5.4-mini
# Embedding model: text-embedding-3-small
# Cohere rerank model: rerank-v4.0-fast

# %% [markdown]
# ## Task 2: Load and Chunk the Cat PDF for Naive RAG
#
# Load the bundled PDF as page-level documents, then split each page into focused chunks for the dense RAG baseline. Preserve source and page metadata on every chunk.

# %%
pdf_path = Path("data/cat_health_guidelines.pdf")
if not pdf_path.exists():
    raise FileNotFoundError(f"Expected the cat PDF at {pdf_path.resolve()}")

pages = [page for page in PyPDFLoader(str(pdf_path)).load() if page.page_content.strip()]
for page_number, page in enumerate(pages, start=1):
    page.metadata.update(
        {
            "source": pdf_path.name,
            "page": page_number,
            "page_id": f"page-{page_number:02d}",
            "document_type": "cat_health_guideline",
        }
    )

print(f"Loaded {len(pages)} text-containing PDF pages.")
print(pages[0].metadata)
# Out:
# Loaded 22 text-containing PDF pages.
# {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 1, 'page_label': '1', 'page_id': 'page-01', 'document_type': 'cat_health_guideline'}

# %%
child_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=120,
    add_start_index=True,
)
children = child_splitter.split_documents(pages)
for index, child in enumerate(children):
    child.metadata["chunk_id"] = f"child-{index:03d}"

print(f"Created {len(children)} child chunks from {len(pages)} parent pages.")
print(children[0].metadata)
print(children[0].page_content[:500])
# Out:
# Created 159 child chunks from 22 parent pages.
# {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 1, 'page_label': '1', 'page_id': 'page-01', 'document_type': 'cat_health_guideline', 'start_index': 0, 'chunk_id': 'child-000'}
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are publishe

# %%
from collections import defaultdict

grouped_data = defaultdict(list)

for index, child in enumerate(children):
    grouped_data[child.metadata["page_id"]].append(child.metadata["chunk_id"])

for page_id, chunk_id in grouped_data.items():
    print(f"page_id: {page_id} -> Chunk Ids: {chunk_id}")
# Out:
# page_id: page-01 -> Chunk Ids: ['child-000', 'child-001', 'child-002', 'child-003', 'child-004', 'child-005', 'child-006']
# page_id: page-02 -> Chunk Ids: ['child-007', 'child-008', 'child-009']
# page_id: page-03 -> Chunk Ids: ['child-010', 'child-011', 'child-012', 'child-013', 'child-014', 'child-015', 'child-016', 'child-017', 'child-018']
# page_id: page-04 -> Chunk Ids: ['child-019']
# page_id: page-05 -> Chunk Ids: ['child-020']
# page_id: page-06 -> Chunk Ids: ['child-021', 'child-022', 'child-023', 'child-024', 'child-025', 'child-026', 'child-027', 'child-028', 'child-029']
# page_id: page-07 -> Chunk Ids: ['child-030', 'child-031', 'child-032', 'child-033', 'child-034', 'child-035']
# page_id: page-08 -> Chunk Ids: ['child-036', 'child-037', 'child-038', 'child-039', 'child-040', 'child-041', 'child-042', 'child-043', 'child-044']
# page_id: page-09 -> Chunk Ids: ['child-045', 'child-046', 'child-047', 'child-048', 'child-049', 'child-050', 'child-051', 'child-052', 'child-053']
# page_id: page-10 -> Chunk Ids: ['child-054', 'child-055', 'child-056', 'child-057', 'child-058', 'child-059', 'child-060', 'child-061', 'child-062']
# page_id: page-11 -> Chunk Ids: ['child-063', 'child-064', 'child-065', 'child-066', 'child-067']
# page_id: page-12 -> Chunk Ids: ['child-068', 'child-069', 'child-070', 'child-071', 'child-072', 'child-073', 'child-074', 'child-075']
# page_id: page-13 -> Chunk Ids: ['child-076', 'child-077', 'child-078', 'child-079', 'child-080', 'child-081', 'child-082', 'child-083', 'child-084']
# page_id: page-14 -> Chunk Ids: ['child-085', 'child-086', 'child-087', 'child-088', 'child-089', 'child-090', 'child-091', 'child-092', 'child-093']
# page_id: page-15 -> Chunk Ids: ['child-094', 'child-095', 'child-096', 'child-097', 'child-098', 'child-099', 'child-100', 'child-101', 'child-102']
# page_id: page-16 -> Chunk Ids: ['child-103', 'child-104', 'child-105', 'child-106', 'child-107', 'child-108', 'child-109', 'child-110']
# page_id: page-17 -> Chunk Ids: ['child-111', 'child-112', 'child-113', 'child-114']
# page_id: page-18 -> Chunk Ids: ['child-115', 'child-116', 'child-117', 'child-118', 'child-119', 'child-120', 'child-121', 'child-122']
# page_id: page-19 -> Chunk Ids: ['child-123', 'child-124', 'child-125', 'child-126', 'child-127', 'child-128', 'child-129', 'child-130', 'child-131', 'child-132', 'child-133']
# page_id: page-20 -> Chunk Ids: ['child-134', 'child-135', 'child-136', 'child-137', 'child-138', 'child-139', 'child-140', 'child-141', 'child-142', 'child-143', 'child-144']
# page_id: page-21 -> Chunk Ids: ['child-145', 'child-146', 'child-147', 'child-148', 'child-149', 'child-150', 'child-151', 'child-152', 'child-153', 'child-154', 'child-155']
# page_id: page-22 -> Chunk Ids: ['child-156', 'child-157', 'child-158']

# %% [markdown]
# ### ❓ Question 1: Traceability
#
# Why should every child chunk retain its source file and page metadata?
#
# Keeping the source file and page info lets you show the user exactly where the answer came from, which is really important for trust and fact-
# checking.
#
# It also makes parent-child retrieval work, meaning you can search with small, focused chunks but then pass the full parent page to the LLM
# so it has enough context.
#
# Finally, it lets you filter searches by metadata and helps with evaluation, since you can map different chunks back to the
# same page IDs to see if they're correct.

# %% [markdown]
# ### Shared Result Representation
#
# All retrievers return the same RetrievedDocument type. Stable chunk and page IDs make the evidence inspectable and keep later comparisons fair.

# %%
def as_retrieved_document(document: Document, score: float | None = None) -> RetrievedDocument:
    return RetrievedDocument(
        id=document.metadata["chunk_id"],
        text=document.page_content,
        score=float(score) if score is not None else None,
        evidence_ids=(document.metadata["page_id"],),
        metadata=dict(document.metadata),
    )


def print_results(results: Sequence[RetrievedDocument], text_limit: int = 260) -> None:
    for rank, result in enumerate(results, start=1):
        page = result.metadata.get("page", "?")
        score = "n/a" if result.score is None else f"{result.score:.4f}"
        print(f"#{rank} | {result.id} | page={page} | score={score}")
        print(result.text[:text_limit].replace("\n", " "))
        print()

# %% [markdown]
# ## Task 3: Naive Dense Vector RAG with In-Memory Qdrant
#
# Session 1 baseline:
#
# question -> OpenAI embedding -> Qdrant nearest-neighbor search -> answer
#
# Create an in-memory Qdrant collection from the child chunks. Retrieve the nearest chunks, then pass only those chunks to the answer model. Use this **naive RAG baseline** for later comparisons.

# %%
# Qdrant stays in memory for this notebook. It disappears when the kernel stops.
vector_store = QdrantVectorStore.from_documents(
    documents=children,
    embedding=embeddings,
    location=":memory:",
    collection_name="cat_health_naive_dense_rag",
)

FIRST_STAGE_K = 8


def dense_retrieve(question: str, k: int = 5) -> list[RetrievedDocument]:
    matches = vector_store.similarity_search_with_score(question, k=k)
    return [as_retrieved_document(document, score) for document, score in matches]


dense_preview = dense_retrieve("What should a senior cat wellness visit cover?", k=4)
print_results(dense_preview)
# Out:
# #1 | child-034 | page=7 | score=0.6789
# disease. Mature Adult and Senior Cats The medical history and examination of mature adult and senior cats will be focused on early detection of disease. Adult and senior cats are often diagnosed with comorbidities. Speci ﬁc questions regarding changes in appet
#
# #2 | child-021 | page=6 | score=0.6741
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are intended to be a starting point from which individualized care re
#
# #3 | child-060 | page=10 | score=0.6188
# study, three 10- to 15-minute exercise sessions per day led to a loss of approximately 1% of body weight in 1 month with no food intake restrictions. 66 Senior Cats Senior cats exhibiting new or unusual behavior should be evaluated for medical conditions. 12 C
#
# #4 | child-036 | page=8 | score=0.6182
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and

# %% [markdown]
# ### Naive RAG Answer
#
# Retrieval quality and answer quality are separate concerns. Pass the nearest dense chunks to the answer model. The same grounded-answer function will later receive context from the other retrievers.

# %%
answer_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Answer only from the provided cat-health guideline context. "
            "Do not diagnose, prescribe, or make an urgent-care decision. "
            "If the context is insufficient, say so. End with a short Sources line.",
        ),
        ("human", "Question: {question}\n\nContext:\n{context}"),
    ]
)


def format_context(documents: Sequence[RetrievedDocument]) -> str:
    blocks = []
    for document in documents:
        page = document.metadata.get("page", "unknown")
        blocks.append(f"[source={document.id}; page={page}]\n{document.text}")
    return "\n\n".join(blocks)


def answer_with_retriever(
    question: str,
    retriever,
    k: int = 4,
) -> AnswerOutput:
    documents = retriever(question, k=k)
    response = answer_model.invoke(
        answer_prompt.format_messages(question=question, context=format_context(documents))
    )
    return AnswerOutput(answer=str(response.content), documents=tuple(documents))


naive_result = answer_with_retriever(
    "What should an owner discuss at a senior cat wellness visit?",
    retriever=dense_retrieve,
)
print(naive_result.answer)
print("\nNaive dense evidence:")
print_results(naive_result.documents, text_limit=200)
# Out:
# At a senior cat wellness visit, an owner should discuss any changes in:
#
# - Appetite
# - Urination and drinking, including more frequent urination or increased thirst
# - Vomiting, hairballs, or diarrhea
# - Nocturnal activity or vocalization
# - Normal habits or activity level
# - Litter box use
#
# These changes can help guide further evaluation for possible disease, pain, mobility issues, cognitive dysfunction, or changes in vision or hearing. The visit should also include discussion of the cat’s diet and overall care.
#
# Sources: child-034 p.7; child-060 p.10; child-028 p.6
#
# Naive dense evidence:
# #1 | child-034 | page=7 | score=0.6958
# disease. Mature Adult and Senior Cats The medical history and examination of mature adult and senior cats will be focused on early detection of disease. Adult and senior cats are often diagnosed with
#
# #2 | child-021 | page=6 | score=0.6693
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are inten
#
# #3 | child-060 | page=10 | score=0.6544
# study, three 10- to 15-minute exercise sessions per day led to a loss of approximately 1% of body weight in 1 month with no food intake restrictions. 66 Senior Cats Senior cats exhibiting new or unusu
#
# #4 | child-028 | page=6 | score=0.6454
# agement Guidelines.18 The role and relationship of the cat with re- spect to the client (i.e., the human –cat bond and the care philosophy of the owner) is also essential to understand. Medical Histor

# %% [markdown]
# ## Task 4: BM25 Sparse Retrieval
#
# BM25 ranks the same child chunks with lexical term matches rather than embeddings. It is useful for abbreviations, age ranges, named conditions, and phrases that dense similarity may blur.
#
# Keep the corpus, chunks, and retrieval depth fixed. The retriever is the only thing that changes.

# %%
def tokenize(text: str) -> list[str]:
    return re.findall(r"[a-z0-9]+", text.lower())


bm25 = BM25Okapi([tokenize(child.page_content) for child in children])


def bm25_retrieve(question: str, k: int = 5) -> list[RetrievedDocument]:
    scores = bm25.get_scores(tokenize(question))
    ranked_indices = sorted(range(len(scores)), key=lambda index: scores[index], reverse=True)
    return [
        as_retrieved_document(children[index], float(scores[index]))
        for index in ranked_indices[:k]
    ]


bm25_preview = bm25_retrieve("What do BCS and MCS stand for?", k=4)
print_results(bm25_preview)
# Out:
# #1 | child-079 | page=13 | score=11.1440
# could result in health problems. 83 No matter the life stage, to help avoid potential nutrient insufﬁciencies, cats should be fed diets labeled with an Association of American Feed Control Of ﬁcials statement of nutritional adequacy. AAHA and the AAFP do not a
#
# #2 | child-029 | page=6 | score=10.8317
# Evaluation and recording of body weight, body condition score (BCS), and muscle condition score (MCS) are important compo- nents of the physical examination at all life stages to allow early 56 JAAHA | 57:2 Mar/Apr 2021
#
# #3 | child-006 | page=1 | score=9.7786
# BCS (body condition score); DER (daily energy requirements); DJD (degenerative joint disease); FCV (feline calicivirus); FeLV (feline leukemia virus); FHV-1 (feline herpesvirus type 1); FIC (feline idiopathic cystitis); FPV (feline panleukopenia virus); GI (ga
#
# #4 | child-082 | page=13 | score=9.7514
# vidual patient. Recommendations can be found in the AAFP ’s Feline Feeding Programs Consensus Statement. 19 Young Adult Cats Energy requirements of cats are in ﬂuenced by a variety of factors including age (i.e., life stage), BCS, MCS, neuter status, health st

# %% [markdown]
# ### ❓ Question 2: When Should BM25 Win?
#
# Which query is more likely to favor BM25: `What do BCS and MCS stand for?` or `How should an owner get ready for a senior-cat wellness visit?` Why?
#
# BM25 works by matching exact keywords, and unique acronyms like "BCS" and "MCS" are rare, specific terms that it can find instantly. On the other
# hand, the query about getting ready for a wellness visit is conceptual and can be phrased in many different ways (like "preparing for a vet
# checkup"). Dense search is much better for that because it looks at the overall semantic meaning rather than exact word matches.
#
# Dense similarity can blur exact tokens like abbreviations (BCS, MCS), ages, or named conditions. BM25 is great because it nails those exact term
# matches that dense search might miss.

# %% [markdown]
# ### 🚀 Activity 1: Dense vs. BM25 Failure Modes
#
# Pick three questions: one paraphrase-heavy question, one exact-term question, and one broad multi-part question. Inspect both result lists before generating an answer.
#
# - Which retriever put the best evidence first?
# - Which retriever returned redundant chunks?
# - Which question type should favor BM25, and why?

# %%
activity_questions = [
    "What does the guideline say about BCS and MCS?",
    "How often should senior cats see a veterinarian?",
    "What factors shape an individualized preventive-care plan?",
]

for question in activity_questions:
    print(f"\nQUESTION: {question}\n")
    print("DENSE")
    print_results(dense_retrieve(question, k=3), text_limit=150)
    print("BM25")
    print_results(bm25_retrieve(question, k=3), text_limit=150)
# Out:
# QUESTION: What does the guideline say about BCS and MCS?
#
# DENSE
# #1 | child-005 | page=1 | score=0.4263
# mendations should not be construed as dictating an exclusive protocol, course of treatment, or procedure. Variations in practice may be war- ranted ba
#
# #2 | child-029 | page=6 | score=0.4119
# Evaluation and recording of body weight, body condition score (BCS), and muscle condition score (MCS) are important compo- nents of the physical exami
#
# #3 | child-006 | page=1 | score=0.3845
# BCS (body condition score); DER (daily energy requirements); DJD (degenerative joint disease); FCV (feline calicivirus); FeLV (feline leukemia virus);
#
# BM25
# #1 | child-029 | page=6 | score=12.3015
# Evaluation and recording of body weight, body condition score (BCS), and muscle condition score (MCS) are important compo- nents of the physical exami
#
# #2 | child-082 | page=13 | score=11.5603
# vidual patient. Recommendations can be found in the AAFP ’s Feline Feeding Programs Consensus Statement. 19 Young Adult Cats Energy requirements of ca
#
# #3 | child-025 | page=6 | score=11.4464
# the cat is reacting to the environment may give clues as to its state of arousal. If the cat is a new patient to the veterinarian, the client may know
#
#
# QUESTION: How often should senior cats see a veterinarian?
#
# DENSE
# #1 | child-021 | page=6 | score=0.7267
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the ve
#
# #2 | child-108 | page=16 | score=0.6229
# Speciﬁc recommendations regarding frequency of laboratory testing by life stage depend on many factors. One consideration regarding testing frequency
#
# #3 | child-034 | page=7 | score=0.6012
# disease. Mature Adult and Senior Cats The medical history and examination of mature adult and senior cats will be focused on early detection of diseas
#
# BM25
# #1 | child-072 | page=12 | score=10.7380
# as a normal felid behavior, 77 is certainly not desirable for solely indoor-housed cats. Most cats that mark have a characteristic pos- ture, whereby
#
# #2 | child-021 | page=6 | score=9.8019
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the ve
#
# #3 | child-082 | page=13 | score=9.0397
# vidual patient. Recommendations can be found in the AAFP ’s Feline Feeding Programs Consensus Statement. 19 Young Adult Cats Energy requirements of ca
#
#
# QUESTION: What factors shape an individualized preventive-care plan?
#
# DENSE
# #1 | child-023 | page=6 | score=0.4436
# setting the agenda for the consultation. An appointment template can be valuable to guide more speci ﬁc questions such as, “Has there been any urinati
#
# #2 | child-113 | page=17 | score=0.4213
# individual basis, and interpretation of test results should be made with an understanding of the sensitivity and speci ﬁcity of the assay. Practice Te
#
# #3 | child-008 | page=2 | score=0.4103
# developed by a T ask Force of experts in feline clinical medicine. Their recommendations are a practical resource to guide individu- alized risk asses
#
# BM25
# #1 | child-023 | page=6 | score=12.2927
# setting the agenda for the consultation. An appointment template can be valuable to guide more speci ﬁc questions such as, “Has there been any urinati
#
# #2 | child-025 | page=6 | score=8.4703
# the cat is reacting to the environment may give clues as to its state of arousal. If the cat is a new patient to the veterinarian, the client may know
#
# #3 | child-001 | page=1 | score=7.6992
# the division of the cat’sl i f e s p a ni n t oaﬁve-stage grouping with four distinct age-related stages (kitten, young adult, mature adult, and senio

# %% [markdown]
#   - Which retriever put the best evidence first?
#
#     It depends on the query. For the acronym question ( BCS and MCS ), BM25 won because it put the exact definition chunk first, while Dense got
#     distracted and put a generic legal disclaimer first. But for the conceptual question ( How often should senior cats see a vet? ), Dense won because BM25 got keyword-matched into a completely irrelevant page about cat territory marking.
#
#   - Which retriever returned redundant chunks?
#
#     Dense is more likely to return redundant chunks. Since adjacent chunks in the text cover the same topic, their embeddings are very similar, which
#     often causes Dense to pull multiple chunks from the same page/section.
#
#   - Which question type should favor BM25, and why?
#
#     Queries with exact terms, abbreviations (like BCS, MCS), specific numbers/ages, or medical codes favor BM25. Dense search tends to blur these exact
#     tokens into broader semantic concepts, whereas BM25 requires the exact word to match.

# %% [markdown]
# ## Task 5: Parent-Child Retrieval
#
# Build a parent-child pipeline on top of the dense retriever:
#
# question -> dense child search in Qdrant -> matching parent PDF pages
#
# Child chunks give the vector store a focused search surface. Parent pages give the answer model surrounding context. Parent-child retrieval adds context recovery to dense retrieval; it is not hybrid retrieval.

# %%
# Parent-page lookup begins here; naive RAG does not need parent records.
parents_by_id = {page.metadata["page_id"]: page for page in pages}


def recover_parent_documents(
    child_candidates: Sequence[RetrievedDocument],
    k: int,
) -> list[RetrievedDocument]:
    parents: list[RetrievedDocument] = []
    seen_parent_ids: set[str] = set()

    for child in child_candidates:
        page_id = child.metadata["page_id"]
        if page_id in seen_parent_ids:
            continue
        parent = parents_by_id[page_id]
        parents.append(
            RetrievedDocument(
                id=page_id,
                text=parent.page_content,
                score=child.score,
                evidence_ids=(page_id,),
                metadata={
                    **parent.metadata,
                    "retrieved_from_child": child.id,
                    "first_stage_score": child.score,
                },
            )
        )
        seen_parent_ids.add(page_id)
        if len(parents) == k:
            break
    return parents


def parent_child_dense_retrieve(question: str, k: int = 5) -> list[RetrievedDocument]:
    child_candidates = dense_retrieve(question, k=FIRST_STAGE_K)
    return recover_parent_documents(child_candidates, k=k)


parent_preview = parent_child_dense_retrieve(
    "How should an owner prepare for a senior cat wellness visit?",
    k=3,
)
print_results(parent_preview, text_limit=400)
# Out:
# #1 | page-06 | page=6 | score=0.6861
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are intended to be a starting point from which individualized care recommenda- tions can be developed. Discussion Items for All Life Stages The Task Force recommends a minimum of annual examinations for all ca
#
# #2 | page-07 | page=7 | score=0.6555
# detection of changes and identi ﬁcation of trends. 20 Obtaining dorsal and lateral photographs of the patient is recommended to facilitate monitoring BCS/MCS as the cat ages, and can help the owner recognize subtle changes. Diseases and conditions that require additional focus during the examination by each life stage are listed in Table 3. Kittens Kittens will have different health risks dependin
#
# #3 | page-10 | page=10 | score=0.6434
# including carpeting, window and door frames, curtains, and couches. Keeping the nails shorter can minimize the damage to household items as well as to people. Moreover, meeting the cat ’s environmental needs may be bene ﬁcial in reducing scratching of unwanted surfaces. 38 Any intercat-related issues should be identi ﬁed and addressed as soon as possible, as these can lead to increased territorial

# %% [markdown]
# ### ❓ Question 3: Search Small, Return Large?
#
# Why does parent-child retrieval search focused child chunks but return the larger parent pages instead of indexing and returning only full pages?
#
#
#   1. Better search accuracy: If you index a whole page, the embedding vector gets "diluted" or blurry because a single page covers too many different
#   details. Small child chunks are focused on a single topic, making it much easier for the vector search to find a precise match.
#
#   2. More context for the LLM: Once you find the right spot using the child chunk, you want to send the entire parent page to the LLM. If you only
#   send the tiny chunk, the LLM might miss crucial surrounding context (like introductory warnings, tables, or list items) and write an incomplete or
#   hallucinated answer.

# %% [markdown]
# # Breakout Room #2: Combine, Rank, and Expand
#
# The first half produced three building blocks: dense retrieval, BM25, and parent-child context recovery. This breakout combines them and compares the results.
#
# In this breakout:
#
# 1. Fuse dense and BM25 rankings with reciprocal rank fusion.
# 2. Rerank the broad hybrid candidate set with Cohere.
# 3. Expand vague questions into multiple searches.
# 4. Compare the trade-offs with the local evaluation library.
#
# Keep only the stages that improve measured retrieval enough to justify their latency.

# %% [markdown]
# ## Task 6: Hybrid Retrieval — Dense + BM25
#
# Dense and BM25 scores use different scales, so raw scores cannot be added directly. Reciprocal rank fusion (RRF) works from their **ranked lists** instead.
#
# The hybrid first stage is:
#
# dense candidates + BM25 candidates -> RRF -> hybrid child candidates
#
# **Hybrid retrieval** combines semantic vector retrieval with sparse lexical retrieval. RRF makes it an **ensemble retriever** by fusing multiple rankings.

# %%
def reciprocal_rank_fusion(
    ranked_lists: Iterable[Sequence[RetrievedDocument]],
    *,
    limit: int,
    rrf_constant: int = 60,
) -> list[RetrievedDocument]:
    scores: dict[str, float] = {}
    documents_by_id: dict[str, RetrievedDocument] = {}

    for ranked_list in ranked_lists:
        for rank, document in enumerate(ranked_list, start=1):
            documents_by_id.setdefault(document.id, document)
            scores[document.id] = scores.get(document.id, 0.0) + 1 / (rrf_constant + rank)

    return [
        replace(
            documents_by_id[document_id],
            score=score,
            metadata={
                **documents_by_id[document_id].metadata,
                "rrf_score": score,
            },
        )
        for document_id, score in sorted(scores.items(), key=lambda item: item[1], reverse=True)[:limit]
    ]


def hybrid_children_retrieve(question: str, k: int = 5) -> list[RetrievedDocument]:
    return reciprocal_rank_fusion(
        [
            dense_retrieve(question, k=FIRST_STAGE_K),
            bm25_retrieve(question, k=FIRST_STAGE_K),
        ],
        limit=k,
    )


hybrid_preview = hybrid_children_retrieve("What does the guideline say about BCS and MCS?", k=4)
print_results(hybrid_preview)
# Out:
# #1 | child-029 | page=6 | score=0.0325
# Evaluation and recording of body weight, body condition score (BCS), and muscle condition score (MCS) are important compo- nents of the physical examination at all life stages to allow early 56 JAAHA | 57:2 Mar/Apr 2021
#
# #2 | child-030 | page=7 | score=0.0310
# detection of changes and identi ﬁcation of trends. 20 Obtaining dorsal and lateral photographs of the patient is recommended to facilitate monitoring BCS/MCS as the cat ages, and can help the owner recognize subtle changes. Diseases and conditions that require
#
# #3 | child-005 | page=1 | score=0.0164
# mendations should not be construed as dictating an exclusive protocol, course of treatment, or procedure. Variations in practice may be war- ranted based on the needs of the individual patient, resources, and limitations unique to each individual practice sett
#
# #4 | child-082 | page=13 | score=0.0161
# vidual patient. Recommendations can be found in the AAFP ’s Feline Feeding Programs Consensus Statement. 19 Young Adult Cats Energy requirements of cats are in ﬂuenced by a variety of factors including age (i.e., life stage), BCS, MCS, neuter status, health st

# %% [markdown]
# ## Task 7: Cohere Reranking over Hybrid Candidates
#
# Use hybrid retrieval to gather a broad set of plausible child chunks from dense and BM25 search. Recover their parent pages, then send those candidates and the question to Cohere Rerank.
#
# dense + BM25 -> RRF -> parent pages -> Cohere Rerank -> final context
#
# The result is a **two-stage hybrid retrieve-then-rerank pipeline**. Cohere scores rank documents within one query and candidate set; do not treat them as universal probabilities.
#
# The custom RRF function supplies the candidate list, so the notebook calls LangChain's `CohereRerank` compressor directly. A single LangChain `BaseRetriever` could instead be wrapped with `ContextualCompressionRetriever`.

# %%
RERANK_CANDIDATE_K = 8


def to_langchain_document(candidate: RetrievedDocument) -> Document:
    return Document(
        page_content=candidate.text,
        metadata={
            **candidate.metadata,
            "retrieved_id": candidate.id,
            "evidence_ids": list(candidate.canonical_evidence_ids),
            "first_stage_score": candidate.score,
        },
    )


def to_reranked_document(document: Document) -> RetrievedDocument:
    relevance_score = document.metadata.get("relevance_score")
    return RetrievedDocument(
        id=document.metadata["retrieved_id"],
        text=document.page_content,
        score=float(relevance_score) if relevance_score is not None else None,
        evidence_ids=tuple(document.metadata["evidence_ids"]),
        metadata=dict(document.metadata),
    )


def rerank_parent_candidates(
    question: str, candidates: Sequence[RetrievedDocument], k: int
) -> list[RetrievedDocument]:
    compressor = CohereRerank(model=RERANK_MODEL, top_n=k)
    reranked_documents = compressor.compress_documents(
        documents=[to_langchain_document(candidate) for candidate in candidates],
        query=question,
    )
    return [to_reranked_document(document) for document in reranked_documents]


def hybrid_reranked_retrieve(question: str, k: int = 5) -> list[RetrievedDocument]:
    child_candidates = hybrid_children_retrieve(question, k=RERANK_CANDIDATE_K)
   # print(f"child rank: {child_candidates}")
    parent_candidates = recover_parent_documents(child_candidates, k=RERANK_CANDIDATE_K)
    return rerank_parent_candidates(question, parent_candidates, k)


rerank_preview = hybrid_reranked_retrieve(
    "How often should senior cats see a veterinarian",
    k=3,
)
print_results(rerank_preview, text_limit=400)
# Out:
# child rank: [RetrievedDocument(id='child-021', text='For example, some senior cats aged 10 years and older may remain in\nexcellent physical condition and would be best treated as a mature\nadult at the veterinarian ’s discretion. The guidelines are intended to\nbe a starting point from which individualized care recommenda-\ntions can be developed.\nDiscussion Items for All Life Stages\nThe Task Force recommends a minimum of annual examinations for\nall cats, with increasing frequency as appropriate for their individual\nneeds.\n6 Senior cats should be seen at least every 6 months and more\nfrequently for those with chronic conditions. More information\ncan be found in the AAFP Senior Care Guidelines .\n12 Seeing patients\nand clients at least annually provides an excellent opportunity for', score=0.03252247488101534, evidence_ids=('page-06',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '6', 'page_id': 'page-06', 'document_type': 'cat_health_guideline', 'start_index': 0, 'chunk_id': 'child-021', '_id': '121490b8c98d4982a23caa9bb96c7add', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03252247488101534}), RetrievedDocument(id='child-009', text='twice as often as cats: 2.3 times/year for dogs versus 1.1 times/year\nfor cats.\n3 This healthcare use imbalance persists to the present day.\nCat owners often express a belief that their pets “do not need\nmedical care.” Two reasons for this misconception are that signs of\nillness and pain are often dif ﬁcult to detect in the sometimes re-\nclusive or stoic cat, and that cats are perceived to be self-suf ﬁcient.\nSpeciﬁc objectives of the guidelines are (1) to de ﬁne distinct\nfeline life stages consistent with how pet owners generally perceive\nTABLE 1\nFeline Life Stages\nª Voren1/iStock, spxChrome/E+, AaronAmat/iStock, AngiePhotos/iStock via Getty Images Plus\n52 JAAHA | 57:2 Mar/Apr 2021', score=0.03076923076923077, evidence_ids=('page-02',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 2, 'page_label': '2', 'page_id': 'page-02', 'document_type': 'cat_health_guideline', 'start_index': 1393, 'chunk_id': 'child-009', '_id': 'bdf8e2d7ba04460e87ce24d5af1481a6', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03076923076923077}), RetrievedDocument(id='child-087', text='92 Being underweight is a common\nproblem in senior cats. 102–104 Prescription therapeutic diets may be\nindicated more often for cats in the mature adult or senior life stage\nfor a variety of reasons (e.g., chronic kidney disease, obesity, hy-\nperthyroidism, chronic enteropathies, osteoarthritis). If a dietary\nchange is indicated, offering the new diet in a separate, adjacent\ncontainer (rather than removing the usual food and replacing it with\nthe new food) will permit the cat to express its preference. Dietary\nchanges should be implemented in the home setting rather than in\nthe practice in order to avoid stress-related food aversions. However,\nintroduction of novel diets to inappetent, hospitalized cats should\nnot be avoided if food consumption is a concern.', score=0.030330882352941176, evidence_ids=('page-14',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 14, 'page_label': ' ...
# #1 | page-06 | page=6 | score=0.8959
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are intended to be a starting point from which individualized care recommenda- tions can be developed. Discussion Items for All Life Stages The Task Force recommends a minimum of annual examinations for all ca
#
# #2 | page-02 | page=2 | score=0.6839
# Introduction The feline patient ’s life stage is the most fundamental presentation factor the practitioner encounters in a regular examination visit. Most of the components of a treatment or healthcare plan are guided by the patient ’s life stage, progressing from kitten to young adult, mature adult, and senior and concluding with the end-of-life stage. Because a cat can transition from one life s
#
# #3 | page-10 | page=10 | score=0.6221
# including carpeting, window and door frames, curtains, and couches. Keeping the nails shorter can minimize the damage to household items as well as to people. Moreover, meeting the cat ’s environmental needs may be bene ﬁcial in reducing scratching of unwanted surfaces. 38 Any intercat-related issues should be identi ﬁed and addressed as soon as possible, as these can lead to increased territorial

# %% [markdown]
# ## Task 8: Multi-Query Retrieval
#
# A user question may be vague, incomplete, or phrased differently from the source. Generate alternate search queries, run each through hybrid first-stage retrieval, and fuse the resulting child rankings.
#
# Multi-query retrieval expands recall on top of the hybrid retrieve-then-rerank pipeline. It also adds model calls, latency, and possible noise.

# %%
# Ask query model for count short distinct queries (one per line and no answers)
multi_query_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Write {count} short, distinct search queries for the cat health guideline PDF. "
            "Return one query per line. Do not answer the question.",
        ),
        ("human", "{question}"),
    ]
)

# Keeps original question and generate variants
def generate_query_variants(question: str, count: int = 3) -> list[str]:
    response = query_model.invoke(
        multi_query_prompt.format_messages(question=question, count=count)
    )
    variants = [question]
    for line in response.content.splitlines():
        candidate = re.sub(r"^\s*(?:[-*]|\d+[.)])\s*", "", line).strip()
        if candidate and candidate.lower() not in {item.lower() for item in variants}:
            variants.append(candidate)
    return variants[: count + 1]

# runs dense _ BM25 for every variant and fuse all lists with RRF.
def multi_query_hybrid_children(question: str, k: int = 5) -> list[RetrievedDocument]:
    ranked_lists: list[Sequence[RetrievedDocument]] = []
    for variant in generate_query_variants(question):
        ranked_lists.append(dense_retrieve(variant, k=FIRST_STAGE_K))
        ranked_lists.append(bm25_retrieve(variant, k=FIRST_STAGE_K))
    return reciprocal_rank_fusion(ranked_lists, limit=k)

# recovrs parents and reranks.
def multi_query_reranked_retrieve(question: str, k: int = 5) -> list[RetrievedDocument]:
    child_candidates = multi_query_hybrid_children(question, k=RERANK_CANDIDATE_K)
    parent_candidates = recover_parent_documents(child_candidates, k=RERANK_CANDIDATE_K)
    return rerank_parent_candidates(question, parent_candidates, k)


question = "How often should senior cats see a veterinarian?"
print(generate_query_variants(question))
print_results(multi_query_reranked_retrieve(question, k=4), text_limit=400)
# Out:
# ['How often should senior cats see a veterinarian?', 'senior cat veterinary checkup frequency guideline PDF', 'cat health guideline senior cats vet visit schedule PDF', 'how often senior cats should see veterinarian PDF']
# #1 | page-06 | page=6 | score=0.8984
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are intended to be a starting point from which individualized care recommenda- tions can be developed. Discussion Items for All Life Stages The Task Force recommends a minimum of annual examinations for all ca
#
# #2 | page-02 | page=2 | score=0.6788
# Introduction The feline patient ’s life stage is the most fundamental presentation factor the practitioner encounters in a regular examination visit. Most of the components of a treatment or healthcare plan are guided by the patient ’s life stage, progressing from kitten to young adult, mature adult, and senior and concluding with the end-of-life stage. Because a cat can transition from one life s
#
# #3 | page-01 | page=1 | score=0.6294
# VETERINARY PRACTICE GUIDELINES 2021 AAHA/AAFP Feline Life Stage Guidelines* Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP, Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp, DVM, PhD, DACVIM ABSTRACT The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and ex
#
# #4 | page-10 | page=10 | score=0.6258
# including carpeting, window and door frames, curtains, and couches. Keeping the nails shorter can minimize the damage to household items as well as to people. Moreover, meeting the cat ’s environmental needs may be bene ﬁcial in reducing scratching of unwanted surfaces. 38 Any intercat-related issues should be identi ﬁed and addressed as soon as possible, as these can lead to increased territorial

# %%
text_reviewed_cases = [
    EvalCase(
        id="life-stage-definitions",
        query="What feline life stages does the guideline define?",
        relevant_evidence_ids=("page-03",),
        tags=("baseline", "life-stage"),
    ),
    EvalCase(
        id="senior-visit-frequency",
        query="How often should senior cats be seen by a veterinarian?",
        relevant_evidence_ids=("page-06",),
        tags=("exact", "senior"),
    ),
    EvalCase(
        id="bcs-mcs",
        query="What do BCS and MCS mean, and why are they recorded?",
        relevant_evidence_ids=("page-06", "page-07"),
        tags=("acronym", "dense-vs-bm25"),
    ),
]

table_layout_challenge = EvalCase(
    id="life-stage-table",
    query="How do wellness discussion items change across feline life stages?",
    relevant_evidence_ids=("page-04", "page-05"),
    tags=("table", "parent-child", "requires-visual-review"),
    notes="Use this after adding a PDF-page vision fallback.",
)

EVAL_K = 4
dense_report = run_retrieval_eval("naive_dense", text_reviewed_cases, dense_retrieve, k=EVAL_K)
bm25_report = run_retrieval_eval("bm25", text_reviewed_cases, bm25_retrieve, k=EVAL_K)
parent_child_report = run_retrieval_eval(
    "dense_parent_child",
    text_reviewed_cases,
    parent_child_dense_retrieve,
    k=EVAL_K,
)
hybrid_rerank_report = run_retrieval_eval(
    "hybrid_rrf_then_cohere",
    text_reviewed_cases,
    hybrid_reranked_retrieve,
    k=EVAL_K,
)
multi_query_report = run_retrieval_eval(
    "multi_query_hybrid_rerank",
    text_reviewed_cases,
    multi_query_reranked_retrieve,
    k=EVAL_K,
)

comparison = compare_reports(
    dense_report,
    bm25_report,
    parent_child_report,
    hybrid_rerank_report,
    multi_query_report,
)
comparison
# Out:
# child rank: [RetrievedDocument(id='child-013', text='ologic basis for six feline life stages remains valid, a ﬁve-stage\ngrouping makes clinical protocols easier to implement and sim-\npliﬁes the dialog between the practice team and cat owners. In this\nregard, the guidelines are not only a useful resource for practitioners\nbut also the basis for client education that is tailored to the feline\npatient’s life stage progression.\nThe items to perform or discuss during each life stage are\nhighlighted in Table 2. V eterinary professionals should use this table\nto identify the differences between each life stage. The text in the\nrest of the guidelines document identi ﬁes select areas in the table\nthat warrant further explanation, but is not intended as a compre-\nhensive review.\nImportance of Feline-Friendly Handling', score=0.01639344262295082, evidence_ids=('page-03',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 3, 'page_label': '3', 'page_id': 'page-03', 'document_type': 'cat_health_guideline', 'start_index': 2107, 'chunk_id': 'child-013', '_id': 'ee7fcf0fa1ce4bddbce4074dd22b76e2', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.01639344262295082}), RetrievedDocument(id='child-025', text='the cat is reacting to the environment may give clues as to its state of\narousal. If the cat is a new patient to the veterinarian, the client may\nknow from previous experience what works well for their pet. For\nexample, does the cat relax when handled in a towel? What is the cat’s\nfavorite treat? What handling methods have worked well or poorly\nin the past? This knowledge and an understanding of reduced-stress\nhandling techniques can help to tailor the approach to each patient.\nNoting these important details in the physical examination record\nwill facilitate successful, reduced-stress future visits and help to\ndevelop individualized approaches that work well for each patient.\nDecreasing stress may reduce confounding results during physical', score=0.01639344262295082, evidence_ids=('page-06',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '6', 'page_id': 'page-06', 'document_type': 'cat_health_guideline', 'start_index': 2720, 'chunk_id': 'child-025', 'rrf_score': 0.01639344262295082}), RetrievedDocument(id='child-035', text='2021 AAHA/AAFP Feline Life Stage Guidelines\nJAAHA.ORG 57', score=0.016129032258064516, evidence_ids=('page-07',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '7', 'page_id': 'page-07', 'document_type': 'cat_health_guideline', 'start_index': 3532, 'chunk_id': 'child-035', '_id': '62d244c2723e485180c9f128adc61a5c', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.016129032258064516}), RetrievedDocument(id='child-004', text='erinary Products, IDEXX Laboratories, Inc., Merck Animal Health, and Zoetis\nPetcare supported the development of the 2021 AAHA/AAFP Feline Life\nStage Guidelinesand resources through an educational grant to AAHA.\n† J. Quimby and S. Gowland were cochairs of the 2021 AAHA/AAFP\nFeline Life Stage Guidelines Task Force.\nThese guidelines were prepared by a Task Force of experts convened\nby the American Animal Hospital Association (AAHA) and  ...
# child rank: [RetrievedDocument(id='child-021', text='For example, some senior cats aged 10 years and older may remain in\nexcellent physical condition and would be best treated as a mature\nadult at the veterinarian ’s discretion. The guidelines are intended to\nbe a starting point from which individualized care recommenda-\ntions can be developed.\nDiscussion Items for All Life Stages\nThe Task Force recommends a minimum of annual examinations for\nall cats, with increasing frequency as appropriate for their individual\nneeds.\n6 Senior cats should be seen at least every 6 months and more\nfrequently for those with chronic conditions. More information\ncan be found in the AAFP Senior Care Guidelines .\n12 Seeing patients\nand clients at least annually provides an excellent opportunity for', score=0.03278688524590164, evidence_ids=('page-06',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '6', 'page_id': 'page-06', 'document_type': 'cat_health_guideline', 'start_index': 0, 'chunk_id': 'child-021', '_id': '121490b8c98d4982a23caa9bb96c7add', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03278688524590164}), RetrievedDocument(id='child-034', text='disease.\nMature Adult and Senior Cats\nThe medical history and examination of mature adult and senior cats\nwill be focused on early detection of disease. Adult and senior cats are\noften diagnosed with comorbidities. Speci ﬁc questions regarding\nchanges in appetite, occurrence of polyuria and polydipsia, vomiting,\nvomiting hairballs, or diarrhea are of key importance to guide di-\nagnostic testing. Discussion should also be held with the client about\nincreased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive\ndysfunction, disease-reduced mobility, pain, or reduced vision.\nTABLE 3\nDiseases and Conditions That Require Particular Focus During Examination, by Life Stage\n2021 AAHA/AAFP Feline Life Stage Guidelines', score=0.030798389007344232, evidence_ids=('page-07',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '7', 'page_id': 'page-07', 'document_type': 'cat_health_guideline', 'start_index': 2785, 'chunk_id': 'child-034', '_id': '59960601ced048f8a3e9857a3ef4510f', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.030798389007344232}), RetrievedDocument(id='child-087', text='92 Being underweight is a common\nproblem in senior cats. 102–104 Prescription therapeutic diets may be\nindicated more often for cats in the mature adult or senior life stage\nfor a variety of reasons (e.g., chronic kidney disease, obesity, hy-\nperthyroidism, chronic enteropathies, osteoarthritis). If a dietary\nchange is indicated, offering the new diet in a separate, adjacent\ncontainer (rather than removing the usual food and replacing it with\nthe new food) will permit the cat to express its preference. Dietary\nchanges should be implemented in the home setting rather than in\nthe practice in order to avoid stress-related food aversions. However,\nintroduction of novel diets to inappetent, hospitalized cats should\nnot be avoided if food consumption is a concern.', score=0.030798389007344232, evidence_ids=('page-14',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_5 ...
# child rank: [RetrievedDocument(id='child-029', text='Evaluation and recording of body weight, body condition score\n(BCS), and muscle condition score (MCS) are important compo-\nnents of the physical examination at all life stages to allow early\n56 JAAHA | 57:2 Mar/Apr 2021', score=0.03252247488101534, evidence_ids=('page-06',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '6', 'page_id': 'page-06', 'document_type': 'cat_health_guideline', 'start_index': 5454, 'chunk_id': 'child-029', '_id': 'de54d5b45946495887c1f7e7a5df3474', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03252247488101534}), RetrievedDocument(id='child-030', text='detection of changes and identi ﬁcation of trends. 20 Obtaining dorsal\nand lateral photographs of the patient is recommended to facilitate\nmonitoring BCS/MCS as the cat ages, and can help the owner\nrecognize subtle changes.\nDiseases and conditions that require additional focus during the\nexamination by each life stage are listed in Table 3.\nKittens\nKittens will have different health risks depending on their lifestyle\nand history, including exposure to other cats and the level of care\nprovided. V accination and parasite control history, health status of\nrelated cats, if known, and clinical signs of upper respiratory or\nparasitic disease are all important areas of focus. Nutritional status\nand weaning history are also important areas of inquiry as orphaned', score=0.03149801587301587, evidence_ids=('page-07',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '7', 'page_id': 'page-07', 'document_type': 'cat_health_guideline', 'start_index': 0, 'chunk_id': 'child-030', '_id': '1c04dd3826a64888959abb2eaff8ebbb', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03149801587301587}), RetrievedDocument(id='child-082', text='vidual patient. Recommendations can be found in the AAFP ’s Feline\nFeeding Programs Consensus Statement.\n19\nYoung Adult Cats\nEnergy requirements of cats are in ﬂuenced by a variety of factors\nincluding age (i.e., life stage), BCS, MCS, neuter status, health status,\nand activity level. Using indirect calorimetry, young adult active cats\nhave been shown to have higher energy requirements compared with\nsenior cats.\n90\nThe amount fed should be adjusted to maintain or encourage\nideal body condition, and a BCS should be documented by the\nveterinarian at each visit.\n91 Photographs (dorsal and lateral) of the\ncat can be obtained and recorded. A BCS of 6/9 or 7/9 is con-\nsidered overweight, and a score of greater than or equal to 8/9 is\nconsidered obese.', score=0.03131881575727918, evidence_ids=('page-13',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 13, 'page_label': '13', 'page_id': 'page-13', 'document_type': 'cat_health_guideline', 'start_index': 4131, 'chunk_id': 'child-082', '_id': '46896a190d5f4bd7b7f7e3901a76abb8', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03131881575727918}), RetrievedDocument(id='child-006', text='BCS (body condition score); DER (daily energy requirements); DJD\n(degenerative joint disease); FCV (feline calicivirus); FeLV (feline leukemia\nvirus); FHV-1 (feline herpesvirus ...
#                    retriever  k  cases  hit_rate  precision_at_k  recall_at_k  \
# 0         dense_parent_child  4      3       1.0        0.333333          1.0
# 1                naive_dense  4      3       1.0        0.333333          1.0
# 2     hybrid_rrf_then_cohere  4      3       1.0        0.333333          1.0
# 3  multi_query_hybrid_rerank  4      3       1.0        0.333333          1.0
# 4                       bm25  4      3       1.0        0.333333          1.0
#
#         mrr  mean_latency_ms
# 0  1.000000       229.680282
# 1  1.000000       242.915442
# 2  0.777778      1158.518978
# 3  0.777778      2610.882685
# 4  0.583333         4.064762

# %%
multi_query_report.case_table()
# Out:
#                   case_id                                              query  \
# 0  life-stage-definitions  What feline life stages does the guideline def...
# 1  senior-visit-frequency  How often should senior cats be seen by a vete...
# 2                 bcs-mcs  What do BCS and MCS mean, and why are they rec...
#
#                      tags                         retrieved_ids  hit@k  \
# 0    baseline, life-stage  [page-18, page-01, page-03, page-07]    1.0
# 1           exact, senior  [page-06, page-02, page-10, page-16]    1.0
# 2  acronym, dense-vs-bm25  [page-06, page-13, page-01, page-07]    1.0
#
#    precision@k  recall@k  reciprocal_rank   latency_ms
# 0         0.25       1.0         0.333333  4152.952291
# 1         0.25       1.0         1.000000  1905.055227
# 2         0.50       1.0         1.000000  1774.640537

# %% [markdown]
# ### Answer-Level Evaluation: Faithfulness and Answer Similarity
#
# Retrieval success does not guarantee that an answer stays grounded in its retrieved passages or covers the reviewed answer. The cases below add reviewed reference answers.
#
# The generic runner follows the same shape as Evalite: data, task, and scorers. This comparison uses the naive dense baseline and the complete multi-query pipeline. Each answer is scored against its own retrieved passages for faithfulness, then against the same reviewed reference answer for semantic similarity.

# %%
answer_reviewed_cases = [
    EvalItem(
        id="life-stage-definitions",
        input="What feline life stages does the guideline define?",
        expected=(
            "The guidelines define kitten (birth to 1 year), young adult (1 through 6 years), "
            "mature adult (7 through 10 years), and senior (over 10 years). End of life can occur at any age."
        ),
        tags=("life-stage",),
    ),
    EvalItem(
        id="senior-visit-frequency",
        input="How often should senior cats be seen by a veterinarian?",
        expected=(
            "All cats should have at least annual examinations. Senior cats should be seen at least every "
            "6 months, with more frequent visits for chronic conditions."
        ),
        tags=("senior",),
    ),
    EvalItem(
        id="bcs-mcs",
        input="What do BCS and MCS mean, and why are they recorded?",
        expected=(
            "BCS is body condition score and MCS is muscle condition score. Along with body weight, "
            "they should be evaluated and recorded at every life stage to identify changes and trends early."
        ),
        tags=("acronym",),
    ),
]

faithfulness_judge = make_openai_faithfulness_judge(evaluation_model)
answer_scorers = [
    faithfulness_scorer(faithfulness_judge),
    answer_similarity_scorer(embeddings),
]


def answerer_for(retriever):
    return lambda question: answer_with_retriever(question, retriever)


dense_answer_report = run_eval(
    "naive_dense_answer",
    data=answer_reviewed_cases,
    task=answerer_for(dense_retrieve),
    scorers=answer_scorers,
)
full_pipeline_answer_report = run_eval(
    "multi_query_hybrid_rerank_answer",
    data=answer_reviewed_cases,
    task=answerer_for(multi_query_reranked_retrieve),
    scorers=answer_scorers,
)

answer_comparison = compare_eval_reports(
    dense_answer_report,
    full_pipeline_answer_report,
)
answer_comparison
# Out:
#                          evaluation  cases  faithfulness  answer_similarity  \
# 0  multi_query_hybrid_rerank_answer      3      1.000000           0.852505
# 1                naive_dense_answer      3      0.916667           0.844917
#
#    mean_task_latency_ms  mean_scoring_latency_ms
# 0           2708.254239              2182.954091
# 1           1125.879369              1718.011874

# %%
full_pipeline_answer_report.case_table()
# Out:
#                   case_id                                              input  \
# 0  life-stage-definitions  What feline life stages does the guideline def...
# 1  senior-visit-frequency  How often should senior cats be seen by a vete...
# 2                 bcs-mcs  What do BCS and MCS mean, and why are they rec...
#
#                                             expected        tags  \
# 0  The guidelines define kitten (birth to 1 year)...  life-stage
# 1  All cats should have at least annual examinati...      senior
# 2  BCS is body condition score and MCS is muscle ...     acronym
#
#                                               output  task_latency_ms  \
# 0  AnswerOutput(answer='The guideline defines fiv...      2520.601941
# 1  AnswerOutput(answer='Senior cats should be see...      2554.302903
# 2  AnswerOutput(answer='BCS means **body conditio...      3049.857872
#
#    scoring_latency_ms  faithfulness  \
# 0         1970.610465           1.0
# 1         1368.162597           1.0
# 2         3210.089210           1.0
#
#                                faithfulness_metadata  answer_similarity  \
# 0  {'verdicts': [{'statement': 'The guideline def...           0.865391
# 1  {'verdicts': [{'statement': 'Senior cats shoul...           0.810900
# 2  {'verdicts': [{'statement': 'BCS means body co...           0.881224
#
#                       answer_similarity_metadata
# 0  {'raw_cosine_similarity': 0.8653910791123021}
# 1   {'raw_cosine_similarity': 0.810899948246378}
# 2  {'raw_cosine_similarity': 0.8812239715537488}

# %% [markdown]
# ### ❓ Question 4: Is More Retrieval Always Better?
#
# Suppose multi-query plus reranking improves recall but lowers MRR and adds noticeable latency. How would faithfulness and answer similarity change your decision about shipping it for every cat-health question?
#
# Faithfulness would decide whether the better recall actually helps the final answer, and answer similarity would tell you whether the answers stay complete and aligned with the reviewed set. If both stay high, I’d be more willing to ship the heavier pipeline for all cat-health questions; if either drops, the extra recall is not translating into better user-facing quality.
#
# So the decision is: **ship only if faithfulness and answer similarity are at least as good as the cheaper baseline, and latency is acceptable**. Otherwise, keep the cheaper path as default and use the heavier pipeline only for hard or recall-sensitive questions.

# %%
# Step 1: Reuse the reports already produced in the notebook so the recommendation
print("RETRIEVAL METRICS")
print(comparison)            # dense / bm25 / parent-child / hybrid+rerank / multi-query

# Answer-level comparison: naive dense baseline vs. full multi-query pipeline:
print("\nANSWER METRICS")
print(answer_comparison)     # faithfulness + answer similarity

# Step 2: Drill into one inspected ranking and one claim-level verdict as evidence.
# Per-case retrieval table for the chosen pipeline (inspect the actual ranking):
hybrid_rerank_report.case_table()        # where did the relevant page land?
# Per-case answer verdicts (faithfulness / similarity per question):
full_pipeline_answer_report.case_table() # is each answer grounded and complete?

# Step 3: Measure the latency cost of the heavier rungs so the trade-off is concrete.
import time

def time_retriever(name, retriever, question, k=4, runs=3):
    # Warm up once (model/API connection), then average a few runs.
    retriever(question, k=k)
    elapsed = []
    for _ in range(runs):
        start = time.perf_counter()
        retriever(question, k=k)
        elapsed.append(time.perf_counter() - start)
    avg_ms = 1000 * sum(elapsed) / len(elapsed)
    print(f"{name:28s} avg {avg_ms:7.1f} ms over {runs} runs")
    return avg_ms

probe = "What should an owner discuss at a senior cat wellness visit?"
time_retriever("naive_dense", dense_retrieve, probe)
time_retriever("hybrid_rrf_then_cohere", hybrid_reranked_retrieve, probe)
time_retriever("multi_query_hybrid_rerank", multi_query_reranked_retrieve, probe)
# Out:
# RETRIEVAL METRICS
#                    retriever  k  cases  hit_rate  precision_at_k  recall_at_k  \
# 0         dense_parent_child  4      3       1.0        0.333333          1.0
# 1                naive_dense  4      3       1.0        0.333333          1.0
# 2     hybrid_rrf_then_cohere  4      3       1.0        0.333333          1.0
# 3  multi_query_hybrid_rerank  4      3       1.0        0.333333          1.0
# 4                       bm25  4      3       1.0        0.333333          1.0
#
#         mrr  mean_latency_ms
# 0  1.000000       174.346513
# 1  1.000000       221.329778
# 2  0.777778       535.104212
# 3  0.777778      2400.582198
# 4  0.583333         1.102345
#
# ANSWER METRICS
#                          evaluation  cases  faithfulness  answer_similarity  \
# 0  multi_query_hybrid_rerank_answer      3      1.000000           0.852505
# 1                naive_dense_answer      3      0.916667           0.844917
#
#    mean_task_latency_ms  mean_scoring_latency_ms
# 0           2708.254239              2182.954091
# 1           1125.879369              1718.011874
# naive_dense                  avg   389.0 ms over 3 runs
# child rank: [RetrievedDocument(id='child-061', text='cause many cat owners do not seek wellness visits, but present their\ncats only for acute care.\n3 The use of pheromones or pre–veterinary visit\npharmaceuticals such as gabapentin or trazodone may reduce stress\nwhile allowing thorough evaluations.\n68–71 As many senior patients may\nbe experiencing some level of pain related to their disease or second-\narily to DJD, analgesics may also be indicated for veterinary visits.\nDJD and/or muscle weakness may initially manifest as a change\nor reduction in jumping or climbing in senior cats. Because of the\nPunishment\nCats should not be punished. Yelling at or startling the cat, spraying the\ncat with water, or other physical forms of punishment only serve to scare\nthe cat and may lead to cats running a way or responding aggressively.', score=0.030798389007344232, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4933, 'chunk_id': 'child-061', '_id': '9888a3db0db24bccb4e7595ed51767b4', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.030798389007344232}), RetrievedDocument(id='child-060', text='study, three 10- to 15-minute exercise sessions per day led to a loss of\napproximately 1% of body weight in 1 month with no food intake\nrestrictions.\n66\nSenior Cats\nSenior cats exhibiting new or unusual behavior should be evaluated for\nmedical conditions.\n12 Changes in litter box usage may indicate urinary\ntract disease, constipation, or diabetes but may also be due to reduced\nmusculoskeletal strength, impaired balance, or onset of pain. V ocali-\nzation, especially nighttime waking, is a common concern and may\nrepresent sensory changes (declin ing hearing and vision), cognitive\ndysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-\nerinary visits may be more challenging for the senior cat, in part be-\ncause many cat owners do not seek wellness visits, but present their', score=0.03057889822595705, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4208, 'chunk_id': 'child-060', '_id': '8887e4ea86ad43cfb56ddceb863f756f', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03057889822595705}), RetrievedDocument(id='child-034', text='disease.\nMature Adult and Senior Cats\nThe medical history and examination of mature adult and senior cats\nwill be focused on early detection of disease. Adult and senior cats are\noften diagnosed with comorbidities. Speci ﬁc questions regarding\nchanges in appetite, occurrence of polyuria and polydipsia, vomiting,\nvomiting hairballs, or diarrhea are of key importance to guide di-\nagnostic testing. Discussion should also be held with the client about\nincreased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive\ndysfunction, disease-reduced mobility, pain, or reduced vision.\nTABLE 3\nDiseases and Conditions That Require Particular Focus During Examination, by Life Stage\n2021 AAHA/AAFP Feline Life Stage Guidelines', score=0.01639344262295082, evidence_ids=('page-07',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', ...
# child rank: [RetrievedDocument(id='child-061', text='cause many cat owners do not seek wellness visits, but present their\ncats only for acute care.\n3 The use of pheromones or pre–veterinary visit\npharmaceuticals such as gabapentin or trazodone may reduce stress\nwhile allowing thorough evaluations.\n68–71 As many senior patients may\nbe experiencing some level of pain related to their disease or second-\narily to DJD, analgesics may also be indicated for veterinary visits.\nDJD and/or muscle weakness may initially manifest as a change\nor reduction in jumping or climbing in senior cats. Because of the\nPunishment\nCats should not be punished. Yelling at or startling the cat, spraying the\ncat with water, or other physical forms of punishment only serve to scare\nthe cat and may lead to cats running a way or responding aggressively.', score=0.030798389007344232, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4933, 'chunk_id': 'child-061', '_id': '9888a3db0db24bccb4e7595ed51767b4', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.030798389007344232}), RetrievedDocument(id='child-060', text='study, three 10- to 15-minute exercise sessions per day led to a loss of\napproximately 1% of body weight in 1 month with no food intake\nrestrictions.\n66\nSenior Cats\nSenior cats exhibiting new or unusual behavior should be evaluated for\nmedical conditions.\n12 Changes in litter box usage may indicate urinary\ntract disease, constipation, or diabetes but may also be due to reduced\nmusculoskeletal strength, impaired balance, or onset of pain. V ocali-\nzation, especially nighttime waking, is a common concern and may\nrepresent sensory changes (declin ing hearing and vision), cognitive\ndysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-\nerinary visits may be more challenging for the senior cat, in part be-\ncause many cat owners do not seek wellness visits, but present their', score=0.03057889822595705, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4208, 'chunk_id': 'child-060', '_id': '8887e4ea86ad43cfb56ddceb863f756f', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03057889822595705}), RetrievedDocument(id='child-034', text='disease.\nMature Adult and Senior Cats\nThe medical history and examination of mature adult and senior cats\nwill be focused on early detection of disease. Adult and senior cats are\noften diagnosed with comorbidities. Speci ﬁc questions regarding\nchanges in appetite, occurrence of polyuria and polydipsia, vomiting,\nvomiting hairballs, or diarrhea are of key importance to guide di-\nagnostic testing. Discussion should also be held with the client about\nincreased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive\ndysfunction, disease-reduced mobility, pain, or reduced vision.\nTABLE 3\nDiseases and Conditions That Require Particular Focus During Examination, by Life Stage\n2021 AAHA/AAFP Feline Life Stage Guidelines', score=0.01639344262295082, evidence_ids=('page-07',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', ...
# child rank: [RetrievedDocument(id='child-061', text='cause many cat owners do not seek wellness visits, but present their\ncats only for acute care.\n3 The use of pheromones or pre–veterinary visit\npharmaceuticals such as gabapentin or trazodone may reduce stress\nwhile allowing thorough evaluations.\n68–71 As many senior patients may\nbe experiencing some level of pain related to their disease or second-\narily to DJD, analgesics may also be indicated for veterinary visits.\nDJD and/or muscle weakness may initially manifest as a change\nor reduction in jumping or climbing in senior cats. Because of the\nPunishment\nCats should not be punished. Yelling at or startling the cat, spraying the\ncat with water, or other physical forms of punishment only serve to scare\nthe cat and may lead to cats running a way or responding aggressively.', score=0.030798389007344232, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4933, 'chunk_id': 'child-061', '_id': '9888a3db0db24bccb4e7595ed51767b4', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.030798389007344232}), RetrievedDocument(id='child-060', text='study, three 10- to 15-minute exercise sessions per day led to a loss of\napproximately 1% of body weight in 1 month with no food intake\nrestrictions.\n66\nSenior Cats\nSenior cats exhibiting new or unusual behavior should be evaluated for\nmedical conditions.\n12 Changes in litter box usage may indicate urinary\ntract disease, constipation, or diabetes but may also be due to reduced\nmusculoskeletal strength, impaired balance, or onset of pain. V ocali-\nzation, especially nighttime waking, is a common concern and may\nrepresent sensory changes (declin ing hearing and vision), cognitive\ndysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-\nerinary visits may be more challenging for the senior cat, in part be-\ncause many cat owners do not seek wellness visits, but present their', score=0.03057889822595705, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4208, 'chunk_id': 'child-060', '_id': '8887e4ea86ad43cfb56ddceb863f756f', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03057889822595705}), RetrievedDocument(id='child-034', text='disease.\nMature Adult and Senior Cats\nThe medical history and examination of mature adult and senior cats\nwill be focused on early detection of disease. Adult and senior cats are\noften diagnosed with comorbidities. Speci ﬁc questions regarding\nchanges in appetite, occurrence of polyuria and polydipsia, vomiting,\nvomiting hairballs, or diarrhea are of key importance to guide di-\nagnostic testing. Discussion should also be held with the client about\nincreased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive\ndysfunction, disease-reduced mobility, pain, or reduced vision.\nTABLE 3\nDiseases and Conditions That Require Particular Focus During Examination, by Life Stage\n2021 AAHA/AAFP Feline Life Stage Guidelines', score=0.01639344262295082, evidence_ids=('page-07',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', ...
# child rank: [RetrievedDocument(id='child-061', text='cause many cat owners do not seek wellness visits, but present their\ncats only for acute care.\n3 The use of pheromones or pre–veterinary visit\npharmaceuticals such as gabapentin or trazodone may reduce stress\nwhile allowing thorough evaluations.\n68–71 As many senior patients may\nbe experiencing some level of pain related to their disease or second-\narily to DJD, analgesics may also be indicated for veterinary visits.\nDJD and/or muscle weakness may initially manifest as a change\nor reduction in jumping or climbing in senior cats. Because of the\nPunishment\nCats should not be punished. Yelling at or startling the cat, spraying the\ncat with water, or other physical forms of punishment only serve to scare\nthe cat and may lead to cats running a way or responding aggressively.', score=0.030798389007344232, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4933, 'chunk_id': 'child-061', '_id': '9888a3db0db24bccb4e7595ed51767b4', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.030798389007344232}), RetrievedDocument(id='child-060', text='study, three 10- to 15-minute exercise sessions per day led to a loss of\napproximately 1% of body weight in 1 month with no food intake\nrestrictions.\n66\nSenior Cats\nSenior cats exhibiting new or unusual behavior should be evaluated for\nmedical conditions.\n12 Changes in litter box usage may indicate urinary\ntract disease, constipation, or diabetes but may also be due to reduced\nmusculoskeletal strength, impaired balance, or onset of pain. V ocali-\nzation, especially nighttime waking, is a common concern and may\nrepresent sensory changes (declin ing hearing and vision), cognitive\ndysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-\nerinary visits may be more challenging for the senior cat, in part be-\ncause many cat owners do not seek wellness visits, but present their', score=0.03057889822595705, evidence_ids=('page-10',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 10, 'page_label': '10', 'page_id': 'page-10', 'document_type': 'cat_health_guideline', 'start_index': 4208, 'chunk_id': 'child-060', '_id': '8887e4ea86ad43cfb56ddceb863f756f', '_collection_name': 'cat_health_naive_dense_rag', 'rrf_score': 0.03057889822595705}), RetrievedDocument(id='child-034', text='disease.\nMature Adult and Senior Cats\nThe medical history and examination of mature adult and senior cats\nwill be focused on early detection of disease. Adult and senior cats are\noften diagnosed with comorbidities. Speci ﬁc questions regarding\nchanges in appetite, occurrence of polyuria and polydipsia, vomiting,\nvomiting hairballs, or diarrhea are of key importance to guide di-\nagnostic testing. Discussion should also be held with the client about\nincreased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive\ndysfunction, disease-reduced mobility, pain, or reduced vision.\nTABLE 3\nDiseases and Conditions That Require Particular Focus During Examination, by Life Stage\n2021 AAHA/AAFP Feline Life Stage Guidelines', score=0.01639344262295082, evidence_ids=('page-07',), metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', ...
# hybrid_rrf_then_cohere       avg   639.0 ms over 3 runs
# multi_query_hybrid_rerank    avg  2757.4 ms over 3 runs
# 2757.3812826691815

# %% [markdown]
# ### 🚀 Activity 2: Make and Defend a Retrieval Recommendation
#
# Choose one retrieval result and one answer-evaluation result, then make a recommendation for the cat-health application.
#
# Include:
#
# 1. Which rung of the retrieval ladder you chose.
# 2. Evidence from at least two metrics and one inspected ranking or claim-level verdict.
# 3. Its cost/latency trade-off.
# 4. One case where you would choose a different rung instead.
#
# A higher aggregate metric does not settle the product decision.
#
# - **Chosen rung:** `multiqueryhybridrerank`.
#
# - **Evidence:** It has **recall@k = 1.0** and **hitrate = 1.0**, and the answer-level row shows **faithfulness = 1.0** with **answer similarity = 0.852505**. The inspected ranking also surfaces relevant cat-health guideline chunks about body condition score, diet history, and senior wellness visits, which supports the retrieval choice.
#
# - **Cost/latency trade-off:** It is much slower, with **mean latency ≈ 2400.6 ms**, and its **MRR = 0.777778**, so the right source is found more often but not ranked as highly, at a clear latency cost.
#
# - **When I’d choose a different rung:** I would use a cheaper rung like **naivedense** for low-risk, routine cat-health questions where speed matters and the baseline already stays faithful enough.

# %% [markdown]
# ## Task 10: Answer with a Selected Pipeline
#
# Pass only the selected pipeline's retrieved context to the answer model. Source labels keep the evidence inspectable. For the two-page life-stage table, inspect the original PDF page when text extraction does not preserve the table structure.

# %%
result = answer_with_retriever(
    "What should an owner discuss at a senior cat wellness visit?",
    retriever=multi_query_reranked_retrieve,
)
print(result.answer)
print("\nRetrieved evidence:")
print_results(result.documents, text_limit=200)
# Out:
# At a senior cat wellness visit, the owner should discuss items that help with early detection of disease and changes in daily function, including:
#
# - Changes in appetite
# - Increased drinking and urination
# - Vomiting, vomiting hairballs, or diarrhea
# - Increased nocturnal activity and vocalization
# - Changes in normal habits or activity, which may suggest cognitive dysfunction, reduced mobility, pain, or reduced vision
#
# The guidelines also note that senior cats should be seen at least every 6 months, and that nutrition, body weight/body condition, and muscle condition are important to review over time. If the context is insufficient for anything more specific, that’s all I can support here.
#
# Sources: page-06, page-07, page-14
#
# Retrieved evidence:
# #1 | page-06 | page=6 | score=0.8839
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are inten
#
# #2 | page-07 | page=7 | score=0.8126
# detection of changes and identi ﬁcation of trends. 20 Obtaining dorsal and lateral photographs of the patient is recommended to facilitate monitoring BCS/MCS as the cat ages, and can help the owner re
#
# #3 | page-01 | page=1 | score=0.7473
# VETERINARY PRACTICE GUIDELINES 2021 AAHA/AAFP Feline Life Stage Guidelines* Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP, Theresa DePorter, DVM, M
#
# #4 | page-14 | page=14 | score=0.7436
# good starting point is to calculate the adult feline patient ’s resting energy requirements (RER) according to the following calculation: RER (kcal per day) ¼ 30 × (body weight in kg) 1 70. Daily ener

# %% [markdown]
# ## Advanced Builds
#
# - Add maximal marginal relevance (MMR) and measure whether it reduces redundant chunks.
# - Add HyDE: generate a hypothetical answer, embed it, and use it as an alternate dense query.
# - Add a PDF-page vision fallback for the life-stage table challenge.
# - Add a second reviewed corpus and use metadata routing to avoid mixing evidence sets.
#
# ## Recap
#
# Build in this order:
#
# 1. Start with a transparent naive dense RAG baseline in in-memory Qdrant.
# 2. Add BM25 to see the value of lexical retrieval.
# 3. Add parent-child recovery to improve answer context.
# 4. Combine dense and BM25 with RRF: hybrid / ensemble retrieval.
# 5. Rerank the hybrid parent candidates with Cohere: a two-stage retrieve-then-rerank pipeline.
# 6. Add multi-query expansion only when its recall benefit justifies its extra latency and cost.
#
# Use the local evaluation library to inspect the retrieved evidence behind every aggregate number.
