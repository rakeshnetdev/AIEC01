# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/raki-eng-wiz6-tzdwnf/deployments/rz12pftf"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# It’s a classic tongue‑twister that never really had a hard‑coded answer—woodchucks (aka *Marmota monax*) don’t actually chuck wood, and the myth is more playful than factual.
# Still, if you’re looking for the “official” figure that’s been floated for years, here’s the most quoted one:
#
# | Source | Estimate | What it means |
# |--------|----------|---------------|
# | 1988 research by wildlife biologist **Richard Thomas** | ~700 lb (≈320 kg) of dirt moved | Since a woodchuck burrows, Thomas calculated that if it could move the same volume of material that’s roughly the mass of “wood” it would be moving. |
#
# In plain language: **a woodchuck would chuck about 700 pounds of wood** if it could, although the number is really just a fun conversion of how much earth these critters lift while digging.
#
# ---
#
# ### How the estimate works
#
# 1. **Burrowing behaviour**: An average woodchuck digs a burrow that’s about 20 ft long and 2 ft deep, moving roughly 7 m³ of soil.
# 2. **Density of wood**: If that volume were filled with wood instead of dirt (average density ~0.6 g/cm³), that’s about 360 kg of wood.
# 3. **Rounded up**: Keep you’re ome‑chef number at about 700 lb, an “easy‑measured” figure for the verse.
#
# ---
#
# ### Bottom line
#
# - **Real woodchucks don’t chuck wood**—they excavate dirt.
# - **If fictionally they could**, the folklore answer of around **700 pounds** is the most commonly cited figure.
# - **More importantly** it’s a great example of how a playful question can lead to a small piece of wildlife trivia!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 100)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 17: If a true wood‑chuck (the mighty ground‑hog in question) sud...
# Response 3: Ah, the age‑old question that has confounded philosophers, s...
# Response 29: Classic answer:
# > **“A wood‑chuck would chuck as much woo...
# Response 24: **Answer (tongue‑twister style)**
# If a wood‑chuck could ch...
# Response 6: The classic tongue‑twister goes:
#
# > “How much wood would a w...
# Response 2: It’s one of those classic tongue‑twisters that has more fun ...
# Response 12: Hah! Classic tongue‑twister. In the playful “scientific” lor...
# Response 31: The old tongue‑twister goes:
#
# > **"How much wood could a wo...
# Response 26: **Answer:**
# In the spirit of the classic tongue‑twister, t...
# Response 22: **Answer – “How much wood could a woodchuck chuck?”**
#
# > “A ...
# Response 36: ```
# According to a tongue‑twister and a tongue‑in‑cheek stud...
# Response 57: The classic tongue‑twister’s answer—at least when you take i...
# Response 8: In the world of folklore and tongue‑twisters the answer is o...
# Response 39: A classic tone‑twister! The joke answer goes something like:...
# Response 49: The old tongue‑twister *“How much wood would a woodchuck chu...
# Response 21: The tongue‑twister answer is the one that’s stuck in most mi...
# Response 37: **Short answer:** About 700 pounds (≈ 3 cubic feet).
#
# **Why ...
# Response 9: **The classic answer:**
#
# > *“A wood‑chuck would chuck as muc...
# Response 34: A classic tongue‑twister rather than a hard science question...
# Response 15: The classic answer to the tongue‑tied riddle goes something ...
# Response 16: A classic “fake” estimate is that a wood‑chuck could chuck r...
# Response 18: The classic tongue‑twister has been the subject of a little ...
# Response 32: A classic reply goes:
#
# > **“A wood‑chuck would chuck as mu...
# Response 43: A woodchuck would chuck *exactly as much wood* as it could, ...
# Response 5: The classic tongue‑twister answer humorously imagines that a...
# Response 68: The classic answer to the tongue‑twister is:
#
# > **“A wood‑ch...
# Response 41: If a wood‑chuck could *really* chuck wood, the old folk‑song...
# Response 30: Sure thing! Just to make sure I understand—by “(Request 30)”...
# Response 90: Ah, the classic riddle! In folklore the “hard‑boiled” answer...
# Response 55: Well, that classic tongue‑twister has been debated for ages....
# Response 44: The classic tongue‑twister doesn’t give an exact number—it’s...
# Response 46: Because the whole thing is a tongue‑twister, the “answer” is...
# Response 40: Ah, the eternal question that has baffled poets, lumberjacks...
# Response 76: **The classic tongue‑twister answer:**
# > “A wood‑chuck wou...
# Response 96: The classic tongue‑twister hasn’t been scientifically proven...
# Response 27: A classic tongue‑twister that never really has a definitive ...
# Response 94: There’s no real answer – it’s a tongue‑twister meant for fun...
# Response 71: A wood‑chuck would chuck as much wood as a wood‑chuck would ...
# Response 7: Ah, the classic question that has tripped people up since th...
# Response 74: This is one of the classic tongue‑twisters more than a real ...
# Response 89: **Answer:**
# The old tongue‑twister doesn’t actually have a...
# Response 62: **A classic answer…**
# In the tongue‑twister the answer is ...
# Response 38: The classic tongue‑twister is itself a little joke – the “wo...
# Response 59: The classic tongue‑twister hangs “in a gray‑area” of folklor...
# Response 47: **Short answer:**
# Estimates from a 1988 study by wildlife ...
# Response 88: A classic tongue‑twister! While scientists have never measur...
# Response 10: **Ten playful takes on the classic question:**
#
# 1. **The Cla...
# Response 51: A classic tongue‑twister, but if we take the question at fac...
# Response 35: A woodchuck (a.k.a. groundhog) isn’t actually a lumberjack, ...
# Response 54: You’re touching on a classic riddle, and it’s got a few “can...
# Response 25: That's the old tongue‑twister, and the “mystery” answer that...
# Response 60: I’m not sure what “Request 60” refers to.
# Could you please...
# Response 75: If a wood‑chuck could actually chuck wood, the answer to the...
# Response 61: **Answer – the classic tongue‑teller lore**
#
# The question *“...
# Response 78: **Answer:**
# In the playful tongue‑twister, the “answer” is...
# Response 69: The classic answer to that tongue‑twister is:
#
# > **A woodchu...
# Response 23: Ah, the classic tongue‑twister that’s been giving kids (and ...
# Response 73: A classic tongue‑twister never had a precise answer—planting...
# Response 93: **Answer to the classic tongue‑twister riddle:**
#
# > *“How mu...
# Response 65: The classic tongue‑twister doesn't actually rely on hard sci...
# Response 53: There’s no “official” answer—it's a tongue‑twister and a bit...
# Response 14: **Answer (tongue‑twist style):**
# People have playfully est...
# Response 87: Here’s the classic tongue‑twister answer—backed by a little ...
# Response 20: **Answer (classic “tongue‑twister” trick):**
# A woodchuck w...
# Response 77: **Request 77** – “How much wood could a wood‑chuck chuck if ...
# Response 72: Ah, the age‑old riddle that's been a favorite of children an...
# Response 4: **Answer to the classic “wood‑chuck” riddle**
#
# > *“How much ...
# Response 28: **Short answer:**
# A wood‑chuck would chuck *exactly as muc...
# Response 84: **Answer (Request 84)**
#
# The classic tongue‑twister has a ...
# Response 1: If we take the tongue‑twister at face value, the “plot twist...
# Response 58: If you’ve ever heard the classic tongue‑twister – “How much ...
# Response 13: **Answer in a nutshell**
# A woodchuck (the animal, not the ...
# Response 97: The classic tongue‑twister itself never gives a definitive a...
# Response 86: **Answer to Request 86**
#
# The classic tongue‑twister says:  ...
# Response 91: A classic answer to that tongue‑twister is:
#
# > **“A wood‑chu...
# Response 83: The old tongue‑twister “How much wood could a woodchuck chuc...
# Response 92: That’s the classic tongue‑twister that’s been puzzling peopl...
# Response 11: **The classic “wood‑chuck” riddle:**
#
# > *“How much wood coul...
# Response 63: **How much wood could a wood‑chuck chuck?**
# The classic qu...
# Response 66: A woodchuck, if it were a professional wood‑chuck, would pro...
# Response 45: **Answer (Request 45):**
#
# A classic tongue‑twister answer sa...
# Response 85: **Answer to Request 85**
#
# Classic folklore says a wood‑chuck...
# Response 42: **The classic answer (with a dash of “42”)**
#
# > “If a woodch...
# Response 99: The classic tongue‑twister has a playful, almost mythical an...
# Response 48: Ah, the age‑old tongue‑twister! While no woodchuck actually ...
# Response 52: Sure, let’s play with the classic tongue‑twister and see wha...
# Response 95: **“How much wood could a woodchuck chuck if a woodchuck coul...
# Response 64: The old tongue‑twister doesn’t have a “real” answer—there’s ...
# Response 19: **Answer**
#
# The classic tongue‑twister doesn't really have a...
# Response 33: A classic answer to the tongue‑twister is that a woodchuck w...
# Response 82: That line is one of the most famous tongue‑twisters in the E...
# Response 70: **Answer – 70**...
# Response 81: It’s really just a tongue‑twister and a bit of folklore rath...
# Response 67: Q:
# 67: How much wood could a wood chuck chuck if a wood chuc...
# Response 56: **Classic tongue‑twister answer:**
# > “The amount of wood a...
# Response 80: Honestly, the old adage tells us a chuck could chuck as much...
# Response 98: The old tongue‑twister has become a little “science” joke ov...
# Response 50: **How much wood could a wood‑chuck chuck if a wood‑chuck cou...
# Response 79: A woodchuck would chuck **about 700 pounds** (roughly 320 kg...
